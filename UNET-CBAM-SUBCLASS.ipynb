# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Conv2DTranspose, Dropout
from tensorflow.keras.layers import MaxPooling2D, UpSampling2D, concatenate, Layer, Dense, Activation
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras import Model
from google.colab import drive
import tensorflow as tf
import numpy as np
import datetime
import warnings
import os

#drive.mount('/content/drive')
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Sub-clases del modelo

# %%
class Incremento(Layer):
    def __init__(self, filtros, kernel_size= 3):
        super(Incremento, self).__init__()
        self.conv1= Conv2D(filtros, kernel_size= kernel_size, padding= "same", activation="relu")
        self.conv2= Conv2D(filtros, kernel_size= kernel_size, padding= "same", activation="relu")
        self.maxpool= MaxPooling2D(3, strides= 2, padding= "same")
        self.bn1= BatchNormalization()
        self.bn2= BatchNormalization()

    def call(self, input_tensor):
        x= self.conv1(input_tensor)        
        x= self.bn1(x)
        x= self.conv2(x)
        x= self.bn2(x)
        resdual= x
        x= self.maxpool(x)
        
        return resdual, x





class Cuello_botella(Layer):
    def __init__(self, filtros_conv, filtros_transpose, kernel_size= 3):
        super(Cuello_botella, self).__init__()
        self.conv1= Conv2D(filtros_conv, kernel_size= kernel_size, padding= "same", activation="relu")
        self.conv2= Conv2D(filtros_conv, kernel_size= kernel_size, padding= "same", activation="relu")
        self.convT= Conv2DTranspose(filtros_transpose, kernel_size= kernel_size, padding= "same", activation= "relu")
        self.bn1= BatchNormalization()
        self.bn2= BatchNormalization()

    def call(self, input_tensor):
        x= self.conv1(input_tensor)
        x= self.bn1(x)
        x= self.conv2(x)
        x= self.bn2(x)
        return self.convT(x)






class Decremento(Layer):
    def __init__(self, filtros, kernel_size= 3):
        super(Decremento, self).__init__()
        self.conv1= Conv2D(filtros, kernel_size= kernel_size, padding= "same", activation="relu")
        self.conv2= Conv2D(filtros, kernel_size= kernel_size, padding= "same", activation="relu")
        self.convT= Conv2DTranspose(int(filtros/2), kernel_size= kernel_size, padding= "same")
        self.bn1= BatchNormalization()
        self.bn2= BatchNormalization()
    
    def call(self, input_tensor):
        x= self.conv1(input_tensor)
        x= self.bn1(x)
        x= self.conv2(x)
        x= self.bn2(x)
        return self.convT(x)





class Crop_and_cat(Layer):
    def __init__(self):
        super(Crop_and_cat, self).__init__()
        self.Upsam= UpSampling2D(2)

    def call(self, input_tensor, res):
        x= self.Upsam(input_tensor)
        return concatenate([x, res])





class Capa_final(Layer):
    def __init__(self, filtros, num_clases, kernel_size= 3):
        super(Capa_final, self).__init__()

        self.conv1= Conv2D(filtros, kernel_size= kernel_size, padding= "same", activation="relu")
        self.conv2= Conv2D(filtros, kernel_size= kernel_size, padding= "same", activation="relu")
        self.conv_f= Conv2D(num_clases, kernel_size= kernel_size, padding= "same", activation="softmax")
        self.bn1= BatchNormalization()
        self.bn2= BatchNormalization()

    def call(self, input_tensor):
        x= self.conv1(input_tensor)
        x= self.bn1(x)
        x= self.conv2(x)
        x= self.bn2(x)
        x= self.conv_f(x)
        return x

# %% [markdown]
# ### Modulos de atención

# %%
class CBAM(Layer):
  def __init__(self, num_kernels, ratio):
    super(CBAM, self).__init__()

    reduccion= int(num_kernels// ratio)
    self.davr_r= Dense(reduccion, activation= 'relu')
    self.dmax_r= Dense(reduccion, activation= 'relu')

    self.davr_a= Dense(num_kernels, activation= 'relu')
    self.dmax_a= Dense(num_kernels, activation= 'relu')

    self.act= Activation('sigmoid')
    self.act_1= Activation('sigmoid')

    self.conv= Conv2D(1, kernel_size= 7, padding= 'same')
    self.batch= BatchNormalization()

  def call(self, entrada):
    favr= tf.reduce_mean(entrada, axis= [-1], keepdims= True)
    fmax= tf.reduce_max(entrada, axis= [-1], keepdims= True)
    x_1= self.davr_r(favr)
    x_2= self.dmax_r(fmax)
    x= tf.add(self.davr_a(x_1), self.dmax_a(x_2))
    x= self.act(x)
    r= tf.math.multiply(entrada, x)

    favr_s= tf.reduce_mean(r, axis= [-1], keepdims= True)
    fmax_s= tf.reduce_max(r, axis= [-1], keepdims= True)
    r= tf.concat([favr_s, fmax_s], axis= -1)
    r= self.conv(r)
    r= self.batch(r)
    return self.act_1(r)

# %%
class UNET(Model):
  def __init__(self, num_clases):
    super(UNET, self).__init__()

    # Atencion encoder
    self.att1= CBAM(64, 16)
    self.att2= CBAM(128, 16)
    self.att3= CBAM(256, 16)
    self.att4= CBAM(256, 16)

    self.dtt1= CBAM(128, 16)
    self.dtt2= CBAM(64, 16)


    self.convi_1= Incremento(64)
    self.convi_2= Incremento(128)
    self.convi_3= Incremento(256)

    self.bot= Cuello_botella(512, 256)

    self.crop1= Crop_and_cat()
    self.crop2= Crop_and_cat()
    self.crop3= Crop_and_cat()


    self.dec1= Decremento(256)
    self.dec2= Decremento(128)

    self.salida= Capa_final(64, num_clases)
    #self.drop= Dropout(rate= 0.5)


  def call(self, entrada_tam):

    res1, x= self.convi_1(entrada_tam)
    x= self.att1(x)

    res2, x= self.convi_2(x)
    x= self.att2(x)

    res3, x= self.convi_3(x)
    x= self.att3(x)
    
    x= self.bot(x)
    x= self.att4(x)

    x= self.crop1(x, res3)
    x= self.dec1(x)
    x= self.dtt1(x)

    x= self.crop2(x, res2)
    x= self.dec2(x)
    x= self.dtt2(x)

    x= self.crop3(x, res1) 
    x= self.salida(x)
    #x= self.drop(x)

    return x

  def build_graph(self, raw_shape):
    x= tf.keras.layers.Input(shape= raw_shape)
    return tf.keras.Model(inputs=[x], outputs= self.call(x))

# %%
raw_input = (320, 320, 3)

mi_modelo= UNET(2)
y= mi_modelo(tf.ones(shape=(0, *raw_input)))

mi_modelo.build_graph(raw_input).summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 320, 320, 3  0           []
#                                 )]
#
#  incremento (Incremento)        ((None, 320, 320, 6  39232       ['input_1[0][0]']
#                                 4),
#                                  (None, 160, 160, 6
#                                 4))
#
#  cbam (CBAM)                    (None, 160, 160, 1)  759         ['incremento[0][1]']
#
#  incremento_1 (Incremento)      ((None, 160, 160, 1  149888      ['cbam[0][0]']
#                                 28),
#                                  (None, 80, 80, 128
#                                 ))
#
#  cbam_1 (CBAM)                  (None, 80, 80, 1)    2439        ['incremento_1[0][1]']
#
#  incremento_2 (Incremento)      ((None, 80, 80, 256  594688      ['cbam_1[0][0]']
#                                 ),
#                                  (None, 40, 40, 256
#                                 ))
#
#  cbam_2 (CBAM)                  (None, 40, 40, 1)    8871        ['incremento_2[0][1]']
#
#  cuello_botella (Cuello_botella  (None, 40, 40, 256)  3548928    ['cbam_2[0][0]']
#  )
#
#  cbam_3 (CBAM)                  (None, 40, 40, 1)    8871        ['cuello_botella[0][0]']
#
#  crop_and_cat (Crop_and_cat)    (None, 80, 80, 257)  0           ['cbam_3[0][0]',
#                                                                   'incremento_2[0][0]']
#
#  decremento (Decremento)        (None, 80, 80, 128)  1479552     ['crop_and_cat[0][0]']
#
#  cbam_4 (CBAM)                  (None, 80, 80, 1)    2439        ['decremento[0][0]']
#
#  crop_and_cat_1 (Crop_and_cat)  (None, 160, 160, 12  0           ['cbam_4[0][0]',
#                                 9)                                'incremento_1[0][0]']
#
#  decremento_1 (Decremento)      (None, 160, 160, 64  371136      ['crop_and_cat_1[0][0]']
#                                 )
#
#  cbam_5 (CBAM)                  (None, 160, 160, 1)  759         ['decremento_1[0][0]']
#
#  crop_and_cat_2 (Crop_and_cat)  (None, 320, 320, 65  0           ['cbam_5[0][0]',
#                                 )                                 'incremento[0][0]']
#
#  capa_final (Capa_final)        (None, 320, 320, 2)  76098       ['crop_and_cat_2[0][0]']
#
# ==================================================================================================
# Total params: 6,283,660
# Trainable params: 6,278,016
# Non-trainable params: 5,644
# __________________________________________________________________________________________________

# %%
# !unzip "/content/drive/MyDrive/Kika/Base de datos/Ent.zip" -d "/content/sample_data/"
# !unzip "/content/drive/MyDrive/Kika/Base de datos/Val.zip" -d "/content/sample_data/"
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#   inflating: /content/sample_data/Ent/mask_patches/8940.png
#   inflating: /content/sample_data/Ent/mask_patches/8941.png
#   inflating: /content/sample_data/Ent/mask_patches/8942.png
#   inflating: /content/sample_data/Ent/mask_patches/8943.png
#   inflating: /content/sample_data/Ent/mask_patches/8944.png
#   inflating: /content/sample_data/Ent/mask_patches/8945.png
#   inflating: /content/sample_data/Ent/mask_patches/8946.png
#   inflating: /content/sample_data/Ent/mask_patches/8947.png
#   inflating: /content/sample_data/Ent/mask_patches/8948.png
#   inflating: /content/sample_data/Ent/mask_patches/8949.png
#   inflating: /content/sample_data/Ent/mask_patches/895.png
#   inflating: /content/sample_data/Ent/mask_patches/8950.png
#   inflating: /content/sample_data/Ent/mask_patches/8951.png
#   inflating: /content/sample_data/Ent/mask_patches/8952.png
#   inflating: /content/sample_data/Ent/mask_patches/8953.png
#   inflating: /content/sample_data/Ent/mask_patches/8954.png
#   inflating: /content/sample_data/Ent/mask_patches/8955.png
#   inflating: /content/sample_data/Ent/mask_patches/8956.png
#   inflating: /content/sample_data/Ent/mask_patches/8957.png
#   inflating: /content/sample_data/Ent/mask_patches/8958.png
#   inflating: /content/sample_data/Ent/mask_patches/8959.png
#   inflating: /content/sample_data/Ent/mask_patches/896.png
#   inflating: /content/sample_data/Ent/mask_patches/8960.png
#   inflating: /content/sample_data/Ent/mask_patches/8961.png
#   inflating: /content/sample_data/Ent/mask_patches/8962.png
#   inflating: /content/sample_data/Ent/mask_patches/8963.png
#   inflating: /content/sample_data/Ent/mask_patches/8964.png
#   inflating: /content/sample_data/Ent/mask_patches/8965.png
#   inflating: /content/sample_data/Ent/mask_patches/8966.png
#   inflating: /content/sample_data/Ent/mask_patches/8967.png
#   inflating: /content/sample_data/Ent/mask_patches/8968.png
#   inflating: /content/sample_data/Ent/mask_patches/8969.png
#   inflating: /content/sample_data/Ent/mask_patches/897.png
#   inflating: /content/sample_data/Ent/mask_patches/8970.png
#   inflating: /content/sample_data/Ent/mask_patches/8971.png
#   inflating: /content/sample_data/Ent/mask_patches/8972.png
#   inflating: /content/sample_data/Ent/mask_patches/8973.png
#   inflating: /content/sample_data/Ent/mask_patches/8974.png
#   inflating: /content/sample_data/Ent/mask_patches/8975.png
#   inflating: /content/sample_data/Ent/mask_patches/8976.png
#   inflating: /content/sample_data/Ent/mask_patches/8977.png
#   inflating: /content/sample_data/Ent/mask_patches/8978.png
#   inflating: /content/sample_data/Ent/mask_patches/8979.png
#   inflating: /content/sample_data/Ent/mask_patches/898.png
#   inflating: /content/sample_data/Ent/mask_patches/8980.png
#   inflating: /content/sample_data/Ent/mask_patches/8981.png
#   inflating: /content/sample_data/Ent/mask_patches/8982.png
#   inflating: /content/sample_data/Ent/mask_patches/8983.png
#   inflating: /content/sample_data/Ent/mask_patches/8984.png
#   inflating: /content/sample_data/Ent/mask_patches/8985.png
#   inflating: /content/sample_data/Ent/mask_patches/8986.png
#   inflating: /content/sample_data/Ent/mask_patches/8987.png
#   inflating: /content/sample_data/Ent/mask_patches/8988.png
#   inflating: /content/sample_data/Ent/mask_patches/8989.png
#   inflating: /content/sample_data/Ent/mask_patches/899.png
#   inflating: /content/sample_data/Ent/mask_patches/8990.png
#   inflating: /content/sample_data/Ent/mask_patches/8991.png
#   inflating: /content/sample_data/Ent/mask_patches/8992.png
#   inflating: /content/sample_data/Ent/mask_patches/8993.png
#   inflating: /content/sample_data/Ent/mask_patches/8994.png
#   inflating: /content/sample_data/Ent/mask_patches/8995.png
#   inflating: /content/sample_data/Ent/mask_patches/8996.png
#   inflating: /content/sample_data/Ent/mask_patches/8997.png
#   inflating: /content/sample_data/Ent/mask_patches/8998.png
#   inflating: /content/sample_data/Ent/mask_patches/8999.png
#   inflating: /content/sample_data/Ent/mask_patches/9.png
#   inflating: /content/sample_data/Ent/mask_patches/90.png
#   inflating: /content/sample_data/Ent/mask_patches/900.png
#   inflating: /content/sample_data/Ent/mask_patches/9000.png
#   inflating: /content/sample_data/Ent/mask_patches/9001.png
#   inflating: /content/sample_data/Ent/mask_patches/9002.png
#   inflating: /content/sample_data/Ent/mask_patches/9003.png
#   inflating: /content/sample_data/Ent/mask_patches/9004.png
#   inflating: /content/sample_data/Ent/mask_patches/9005.png
#   inflating: /content/sample_data/Ent/mask_patches/9006.png
#   inflating: /content/sample_data/Ent/mask_patches/9007.png
#   inflating: /content/sample_data/Ent/mask_patches/9008.png
#   inflating: /content/sample_data/Ent/mask_patches/9009.png
#   inflating: /content/sample_data/Ent/mask_patches/901.png
#   inflating: /content/sample_data/Ent/mask_patches/9010.png
#   inflating: /content/sample_data/Ent/mask_patches/9011.png
#   inflating: /content/sample_data/Ent/mask_patches/9012.png
#   inflating: /content/sample_data/Ent/mask_patches/9013.png
#   inflating: /content/sample_data/Ent/mask_patches/9014.png
#   inflating: /content/sample_data/Ent/mask_patches/9015.png
#   inflating: /content/sample_data/Ent/mask_patches/9016.png
#   inflating: /content/sample_data/Ent/mask_patches/9017.png
#   inflating: /content/sample_data/Ent/mask_patches/9018.png
#   inflating: /content/sample_data/Ent/mask_patches/9019.png
#   inflating: /content/sample_data/Ent/mask_patches/902.png
#   inflating: /content/sample_data/Ent/mask_patches/9020.png
#   inflating: /content/sample_data/Ent/mask_patches/9021.png
#   inflating: /content/sample_data/Ent/mask_patches/9022.png
#   inflating: /content/sample_data/Ent/mask_patches/9023.png
#   inflating: /content/sample_data/Ent/mask_patches/9024.png
#   inflating: /content/sample_data/Ent/mask_patches/9025.png
#   inflating: /content/sample_data/Ent/mask_patches/9026.png
#   inflating: /content/sample_data/Ent/mask_patches/9027.png
#   inflating: /content/sample_data/Ent/mask_patches/9028.png
#   inflating: /content/sample_data/Ent/mask_patches/9029.png
#   inflating: /content/sample_data/Ent/mask_patches/903.png
#   inflating: /content/sample_data/Ent/mask_patches/9030.png
#   inflating: /content/sample_data/Ent/mask_patches/9031.png
#   inflating: /content/sample_data/Ent/mask_patches/9032.png
#   inflating: /content/sample_data/Ent/mask_patches/9033.png
#   inflating: /content/sample_data/Ent/mask_patches/9034.png
#   inflating: /content/sample_data/Ent/mask_patches/9035.png
#   inflating: /content/sample_data/Ent/mask_patches/9036.png
#   inflating: /content/sample_data/Ent/mask_patches/9037.png
#   inflating: /content/sample_data/Ent/mask_patches/9038.png
#   inflating: /content/sample_data/Ent/mask_patches/9039.png
#   inflating: /content/sample_data/Ent/mask_patches/904.png
#   inflating: /content/sample_data/Ent/mask_patches/9040.png
#   inflating: /content/sample_data/Ent/mask_patches/9041.png
#   inflating: /content/sample_data/Ent/mask_patches/9042.png
#   inflating: /content/sample_data/Ent/mask_patches/9043.png
#   inflating: /content/sample_data/Ent/mask_patches/9044.png
#   inflating: /content/sample_data/Ent/mask_patches/9045.png
#   inflating: /content/sample_data/Ent/mask_patches/9046.png
#   inflating: /content/sample_data/Ent/mask_patches/9047.png
#   inflating: /content/sample_data/Ent/mask_patches/9048.png
#   inflating: /content/sample_data/Ent/mask_patches/9049.png
#   inflating: /content/sample_data/Ent/mask_patches/905.png
#   inflating: /content/sample_data/Ent/mask_patches/9050.png
#   inflating: /content/sample_data/Ent/mask_patches/9051.png
#   inflating: /content/sample_data/Ent/mask_patches/9052.png
#   inflating: /content/sample_data/Ent/mask_patches/9053.png
#   inflating: /content/sample_data/Ent/mask_patches/9054.png
#   inflating: /content/sample_data/Ent/mask_patches/9055.png
#   inflating: /content/sample_data/Ent/mask_patches/9056.png
#   inflating: /content/sample_data/Ent/mask_patches/9057.png
#   inflating: /content/sample_data/Ent/mask_patches/9058.png
#   inflating: /content/sample_data/Ent/mask_patches/9059.png
#   inflating: /content/sample_data/Ent/mask_patches/906.png
#   inflating: /content/sample_data/Ent/mask_patches/9060.png
#   inflating: /content/sample_data/Ent/mask_patches/9061.png
#   inflating: /content/sample_data/Ent/mask_patches/9062.png
#   inflating: /content/sample_data/Ent/mask_patches/9063.png
#   inflating: /content/sample_data/Ent/mask_patches/9064.png
#   inflating: /content/sample_data/Ent/mask_patches/9065.png
#   inflating: /content/sample_data/Ent/mask_patches/9066.png
#   inflating: /content/sample_data/Ent/mask_patches/9067.png
#   inflating: /content/sample_data/Ent/mask_patches/9068.png
#   inflating: /content/sample_data/Ent/mask_patches/9069.png
#   inflating: /content/sample_data/Ent/mask_patches/907.png
#   inflating: /content/sample_data/Ent/mask_patches/9070.png
#   inflating: /content/sample_data/Ent/mask_patches/9071.png
#   inflating: /content/sample_data/Ent/mask_patches/9072.png
#   inflating: /content/sample_data/Ent/mask_patches/9073.png
#   inflating: /content/sample_data/Ent/mask_patches/9074.png
#   inflating: /content/sample_data/Ent/mask_patches/9075.png
#   inflating: /content/sample_data/Ent/mask_patches/9076.png
#   inflating: /content/sample_data/Ent/mask_patches/9077.png
#   inflating: /content/sample_data/Ent/mask_patches/9078.png
#   inflating: /content/sample_data/Ent/mask_patches/9079.png
#   inflating: /content/sample_data/Ent/mask_patches/908.png
#   inflating: /content/sample_data/Ent/mask_patches/9080.png
#   inflating: /content/sample_data/Ent/mask_patches/9081.png
#   inflating: /content/sample_data/Ent/mask_patches/9082.png
#   inflating: /content/sample_data/Ent/mask_patches/9083.png
#   inflating: /content/sample_data/Ent/mask_patches/9084.png
#   inflating: /content/sample_data/Ent/mask_patches/9085.png
#   inflating: /content/sample_data/Ent/mask_patches/9086.png
#   inflating: /content/sample_data/Ent/mask_patches/9087.png
#   inflating: /content/sample_data/Ent/mask_patches/9088.png
#   inflating: /content/sample_data/Ent/mask_patches/9089.png
#   inflating: /content/sample_data/Ent/mask_patches/909.png
#   inflating: /content/sample_data/Ent/mask_patches/9090.png
#   inflating: /content/sample_data/Ent/mask_patches/9091.png
#   inflating: /content/sample_data/Ent/mask_patches/9092.png
#   inflating: /content/sample_data/Ent/mask_patches/9093.png
#   inflating: /content/sample_data/Ent/mask_patches/9094.png
#   inflating: /content/sample_data/Ent/mask_patches/9095.png
#   inflating: /content/sample_data/Ent/mask_patches/9096.png
#   inflating: /content/sample_data/Ent/mask_patches/9097.png
#   inflating: /content/sample_data/Ent/mask_patches/9098.png
#   inflating: /content/sample_data/Ent/mask_patches/9099.png
#   inflating: /content/sample_data/Ent/mask_patches/91.png
#   inflating: /content/sample_data/Ent/mask_patches/910.png
#   inflating: /content/sample_data/Ent/mask_patches/9100.png
#   inflating: /content/sample_data/Ent/mask_patches/9101.png
#   inflating: /content/sample_data/Ent/mask_patches/9102.png
#   inflating: /content/sample_data/Ent/mask_patches/9103.png
#   inflating: /content/sample_data/Ent/mask_patches/9104.png
#   inflating: /content/sample_data/Ent/mask_patches/9105.png
#   inflating: /content/sample_data/Ent/mask_patches/9106.png
#   inflating: /content/sample_data/Ent/mask_patches/9107.png
#   inflating: /content/sample_data/Ent/mask_patches/9108.png
#   inflating: /content/sample_data/Ent/mask_patches/9109.png
#   inflating: /content/sample_data/Ent/mask_patches/911.png
#   inflating: /content/sample_data/Ent/mask_patches/9110.png
#   inflating: /content/sample_data/Ent/mask_patches/9111.png
#   inflating: /content/sample_data/Ent/mask_patches/9112.png
#   inflating: /content/sample_data/Ent/mask_patches/9113.png
#   inflating: /content/sample_data/Ent/mask_patches/9114.png
#   inflating: /content/sample_data/Ent/mask_patches/9115.png
#   inflating: /content/sample_data/Ent/mask_patches/9116.png
#   inflating: /content/sample_data/Ent/mask_patches/9117.png
#   inflating: /content/sample_data/Ent/mask_patches/9118.png
#   inflating: /content/sample_data/Ent/mask_patches/9119.png
#   inflating: /content/sample_data/Ent/mask_patches/912.png
#   inflating: /content/sample_data/Ent/mask_patches/9120.png
#   inflating: /content/sample_data/Ent/mask_patches/9121.png
#   inflating: /content/sample_data/Ent/mask_patches/9122.png
#   inflating: /content/sample_data/Ent/mask_patches/9123.png
#   inflating: /content/sample_data/Ent/mask_patches/9124.png
#   inflating: /content/sample_data/Ent/mask_patches/9125.png
#   inflating: /content/sample_data/Ent/mask_patches/9126.png
#   inflating: /content/sample_data/Ent/mask_patches/9127.png
#   inflating: /content/sample_data/Ent/mask_patches/9128.png
#   inflating: /content/sample_data/Ent/mask_patches/9129.png
#   inflating: /content/sample_data/Ent/mask_patches/913.png
#   inflating: /content/sample_data/Ent/mask_patches/9130.png
#   inflating: /content/sample_data/Ent/mask_patches/9131.png
#   inflating: /content/sample_data/Ent/mask_patches/9132.png
#   inflating: /content/sample_data/Ent/mask_patches/9133.png
#   inflating: /content/sample_data/Ent/mask_patches/9134.png
#   inflating: /content/sample_data/Ent/mask_patches/9135.png
#   inflating: /content/sample_data/Ent/mask_patches/9136.png
#   inflating: /content/sample_data/Ent/mask_patches/9137.png
#   inflating: /content/sample_data/Ent/mask_patches/9138.png
#   inflating: /content/sample_data/Ent/mask_patches/9139.png
#   inflating: /content/sample_data/Ent/mask_patches/914.png
#   inflating: /content/sample_data/Ent/mask_patches/9140.png
#   inflating: /content/sample_data/Ent/mask_patches/9141.png
#   inflating: /content/sample_data/Ent/mask_patches/9142.png
#   inflating: /content/sample_data/Ent/mask_patches/9143.png
#   inflating: /content/sample_data/Ent/mask_patches/9144.png
#   inflating: /content/sample_data/Ent/mask_patches/9145.png
#   inflating: /content/sample_data/Ent/mask_patches/9146.png
#   inflating: /content/sample_data/Ent/mask_patches/9147.png
#   inflating: /content/sample_data/Ent/mask_patches/9148.png
#   inflating: /content/sample_data/Ent/mask_patches/9149.png
#   inflating: /content/sample_data/Ent/mask_patches/915.png
#   inflating: /content/sample_data/Ent/mask_patches/9150.png
#   inflating: /content/sample_data/Ent/mask_patches/9151.png
#   inflating: /content/sample_data/Ent/mask_patches/9152.png
#   inflating: /content/sample_data/Ent/mask_patches/9153.png
#   inflating: /content/sample_data/Ent/mask_patches/9154.png
#   inflating: /content/sample_data/Ent/mask_patches/9155.png
#   inflating: /content/sample_data/Ent/mask_patches/9156.png
#   inflating: /content/sample_data/Ent/mask_patches/9157.png
#   inflating: /content/sample_data/Ent/mask_patches/9158.png
#   inflating: /content/sample_data/Ent/mask_patches/9159.png
#   inflating: /content/sample_data/Ent/mask_patches/916.png
#   inflating: /content/sample_data/Ent/mask_patches/9160.png
#   inflating: /content/sample_data/Ent/mask_patches/9161.png
#   inflating: /content/sample_data/Ent/mask_patches/9162.png
#   inflating: /content/sample_data/Ent/mask_patches/9163.png
#   inflating: /content/sample_data/Ent/mask_patches/9164.png
#   inflating: /content/sample_data/Ent/mask_patches/9165.png
#   inflating: /content/sample_data/Ent/mask_patches/9166.png
#   inflating: /content/sample_data/Ent/mask_patches/9167.png
#   inflating: /content/sample_data/Ent/mask_patches/9168.png
#   inflating: /content/sample_data/Ent/mask_patches/9169.png
#   inflating: /content/sample_data/Ent/mask_patches/917.png
#   inflating: /content/sample_data/Ent/mask_patches/9170.png
#   inflating: /content/sample_data/Ent/mask_patches/9171.png
#   inflating: /content/sample_data/Ent/mask_patches/9172.png
#   inflating: /content/sample_data/Ent/mask_patches/9173.png
#   inflating: /content/sample_data/Ent/mask_patches/9174.png
#   inflating: /content/sample_data/Ent/mask_patches/9175.png
#   inflating: /content/sample_data/Ent/mask_patches/9176.png
#   inflating: /content/sample_data/Ent/mask_patches/9177.png
#   inflating: /content/sample_data/Ent/mask_patches/9178.png
#   inflating: /content/sample_data/Ent/mask_patches/9179.png
#   inflating: /content/sample_data/Ent/mask_patches/918.png
#   inflating: /content/sample_data/Ent/mask_patches/9180.png
#   inflating: /content/sample_data/Ent/mask_patches/9181.png
#   inflating: /content/sample_data/Ent/mask_patches/9182.png
#   inflating: /content/sample_data/Ent/mask_patches/9183.png
#   inflating: /content/sample_data/Ent/mask_patches/9184.png
#   inflating: /content/sample_data/Ent/mask_patches/9185.png
#   inflating: /content/sample_data/Ent/mask_patches/9186.png
#   inflating: /content/sample_data/Ent/mask_patches/9187.png
#   inflating: /content/sample_data/Ent/mask_patches/9188.png
#   inflating: /content/sample_data/Ent/mask_patches/9189.png
#   inflating: /content/sample_data/Ent/mask_patches/919.png
#   inflating: /content/sample_data/Ent/mask_patches/9190.png
#   inflating: /content/sample_data/Ent/mask_patches/9191.png
#   inflating: /content/sample_data/Ent/mask_patches/9192.png
#   inflating: /content/sample_data/Ent/mask_patches/9193.png
#   inflating: /content/sample_data/Ent/mask_patches/9194.png
#   inflating: /content/sample_data/Ent/mask_patches/9195.png
#   inflating: /content/sample_data/Ent/mask_patches/9196.png
#   inflating: /content/sample_data/Ent/mask_patches/9197.png
#   inflating: /content/sample_data/Ent/mask_patches/9198.png
#   inflating: /content/sample_data/Ent/mask_patches/9199.png
#   inflating: /content/sample_data/Ent/mask_patches/92.png
#   inflating: /content/sample_data/Ent/mask_patches/920.png
#   inflating: /content/sample_data/Ent/mask_patches/9200.png
#   inflating: /content/sample_data/Ent/mask_patches/9201.png
#   inflating: /content/sample_data/Ent/mask_patches/9202.png
#   inflating: /content/sample_data/Ent/mask_patches/9203.png
#   inflating: /content/sample_data/Ent/mask_patches/9204.png
#   inflating: /content/sample_data/Ent/mask_patches/9205.png
#   inflating: /content/sample_data/Ent/mask_patches/9206.png
#   inflating: /content/sample_data/Ent/mask_patches/9207.png
#   inflating: /content/sample_data/Ent/mask_patches/9208.png
#   inflating: /content/sample_data/Ent/mask_patches/9209.png
#   inflating: /content/sample_data/Ent/mask_patches/921.png
#   inflating: /content/sample_data/Ent/mask_patches/9210.png
#   inflating: /content/sample_data/Ent/mask_patches/9211.png
#   inflating: /content/sample_data/Ent/mask_patches/9212.png
#   inflating: /content/sample_data/Ent/mask_patches/9213.png
#   inflating: /content/sample_data/Ent/mask_patches/9214.png
#   inflating: /content/sample_data/Ent/mask_patches/9215.png
#   inflating: /content/sample_data/Ent/mask_patches/9216.png
#   inflating: /content/sample_data/Ent/mask_patches/9217.png
#   inflating: /content/sample_data/Ent/mask_patches/9218.png
#   inflating: /content/sample_data/Ent/mask_patches/9219.png
#   inflating: /content/sample_data/Ent/mask_patches/922.png
#   inflating: /content/sample_data/Ent/mask_patches/9220.png
#   inflating: /content/sample_data/Ent/mask_patches/9221.png
#   inflating: /content/sample_data/Ent/mask_patches/9222.png
#   inflating: /content/sample_data/Ent/mask_patches/9223.png
#   inflating: /content/sample_data/Ent/mask_patches/9224.png
#   inflating: /content/sample_data/Ent/mask_patches/9225.png
#   inflating: /content/sample_data/Ent/mask_patches/9226.png
#   inflating: /content/sample_data/Ent/mask_patches/9227.png
#   inflating: /content/sample_data/Ent/mask_patches/9228.png
#   inflating: /content/sample_data/Ent/mask_patches/9229.png
#   inflating: /content/sample_data/Ent/mask_patches/923.png
#   inflating: /content/sample_data/Ent/mask_patches/9230.png
#   inflating: /content/sample_data/Ent/mask_patches/9231.png
#   inflating: /content/sample_data/Ent/mask_patches/9232.png
#   inflating: /content/sample_data/Ent/mask_patches/9233.png
#   inflating: /content/sample_data/Ent/mask_patches/9234.png
#   inflating: /content/sample_data/Ent/mask_patches/9235.png
#   inflating: /content/sample_data/Ent/mask_patches/9236.png
#   inflating: /content/sample_data/Ent/mask_patches/9237.png
#   inflating: /content/sample_data/Ent/mask_patches/9238.png
#   inflating: /content/sample_data/Ent/mask_patches/9239.png
#   inflating: /content/sample_data/Ent/mask_patches/924.png
#   inflating: /content/sample_data/Ent/mask_patches/9240.png
#   inflating: /content/sample_data/Ent/mask_patches/9241.png
#   inflating: /content/sample_data/Ent/mask_patches/9242.png
#   inflating: /content/sample_data/Ent/mask_patches/9243.png
#   inflating: /content/sample_data/Ent/mask_patches/9244.png
#   inflating: /content/sample_data/Ent/mask_patches/9245.png
#   inflating: /content/sample_data/Ent/mask_patches/9246.png
#   inflating: /content/sample_data/Ent/mask_patches/9247.png
#   inflating: /content/sample_data/Ent/mask_patches/9248.png
#   inflating: /content/sample_data/Ent/mask_patches/9249.png
#   inflating: /content/sample_data/Ent/mask_patches/925.png
#   inflating: /content/sample_data/Ent/mask_patches/9250.png
#   inflating: /content/sample_data/Ent/mask_patches/9251.png
#   inflating: /content/sample_data/Ent/mask_patches/9252.png
#   inflating: /content/sample_data/Ent/mask_patches/9253.png
#   inflating: /content/sample_data/Ent/mask_patches/9254.png
#   inflating: /content/sample_data/Ent/mask_patches/9255.png
#   inflating: /content/sample_data/Ent/mask_patches/9256.png
#   inflating: /content/sample_data/Ent/mask_patches/9257.png
#   inflating: /content/sample_data/Ent/mask_patches/9258.png
#   inflating: /content/sample_data/Ent/mask_patches/9259.png
#   inflating: /content/sample_data/Ent/mask_patches/926.png
#   inflating: /content/sample_data/Ent/mask_patches/9260.png
#   inflating: /content/sample_data/Ent/mask_patches/9261.png
#   inflating: /content/sample_data/Ent/mask_patches/9262.png
#   inflating: /content/sample_data/Ent/mask_patches/9263.png
#   inflating: /content/sample_data/Ent/mask_patches/9264.png
#   inflating: /content/sample_data/Ent/mask_patches/9265.png
#   inflating: /content/sample_data/Ent/mask_patches/9266.png
#   inflating: /content/sample_data/Ent/mask_patches/9267.png
#   inflating: /content/sample_data/Ent/mask_patches/9268.png
#   inflating: /content/sample_data/Ent/mask_patches/9269.png
#   inflating: /content/sample_data/Ent/mask_patches/927.png
#   inflating: /content/sample_data/Ent/mask_patches/9270.png
#   inflating: /content/sample_data/Ent/mask_patches/9271.png
#   inflating: /content/sample_data/Ent/mask_patches/9272.png
#   inflating: /content/sample_data/Ent/mask_patches/9273.png
#   inflating: /content/sample_data/Ent/mask_patches/9274.png
#   inflating: /content/sample_data/Ent/mask_patches/9275.png
#   inflating: /content/sample_data/Ent/mask_patches/9276.png
#   inflating: /content/sample_data/Ent/mask_patches/9277.png
#   inflating: /content/sample_data/Ent/mask_patches/9278.png
#   inflating: /content/sample_data/Ent/mask_patches/9279.png
#   inflating: /content/sample_data/Ent/mask_patches/928.png
#   inflating: /content/sample_data/Ent/mask_patches/9280.png
#   inflating: /content/sample_data/Ent/mask_patches/9281.png
#   inflating: /content/sample_data/Ent/mask_patches/9282.png
#   inflating: /content/sample_data/Ent/mask_patches/9283.png
#   inflating: /content/sample_data/Ent/mask_patches/9284.png
#   inflating: /content/sample_data/Ent/mask_patches/9285.png
#   inflating: /content/sample_data/Ent/mask_patches/9286.png
#   inflating: /content/sample_data/Ent/mask_patches/9287.png
#   inflating: /content/sample_data/Ent/mask_patches/9288.png
#   inflating: /content/sample_data/Ent/mask_patches/9289.png
#   inflating: /content/sample_data/Ent/mask_patches/929.png
#   inflating: /content/sample_data/Ent/mask_patches/9290.png
#   inflating: /content/sample_data/Ent/mask_patches/9291.png
#   inflating: /content/sample_data/Ent/mask_patches/9292.png
#   inflating: /content/sample_data/Ent/mask_patches/9293.png
#   inflating: /content/sample_data/Ent/mask_patches/9294.png
#   inflating: /content/sample_data/Ent/mask_patches/9295.png
#   inflating: /content/sample_data/Ent/mask_patches/9296.png
#   inflating: /content/sample_data/Ent/mask_patches/9297.png
#   inflating: /content/sample_data/Ent/mask_patches/9298.png
#   inflating: /content/sample_data/Ent/mask_patches/9299.png
#   inflating: /content/sample_data/Ent/mask_patches/93.png
#   inflating: /content/sample_data/Ent/mask_patches/930.png
#   inflating: /content/sample_data/Ent/mask_patches/9300.png
#   inflating: /content/sample_data/Ent/mask_patches/9301.png
#   inflating: /content/sample_data/Ent/mask_patches/9302.png
#   inflating: /content/sample_data/Ent/mask_patches/9303.png
#   inflating: /content/sample_data/Ent/mask_patches/9304.png
#   inflating: /content/sample_data/Ent/mask_patches/9305.png
#   inflating: /content/sample_data/Ent/mask_patches/9306.png
#   inflating: /content/sample_data/Ent/mask_patches/9307.png
#   inflating: /content/sample_data/Ent/mask_patches/9308.png
#   inflating: /content/sample_data/Ent/mask_patches/9309.png
#   inflating: /content/sample_data/Ent/mask_patches/931.png
#   inflating: /content/sample_data/Ent/mask_patches/9310.png
#   inflating: /content/sample_data/Ent/mask_patches/9311.png
#   inflating: /content/sample_data/Ent/mask_patches/9312.png
#   inflating: /content/sample_data/Ent/mask_patches/9313.png
#   inflating: /content/sample_data/Ent/mask_patches/9314.png
#   inflating: /content/sample_data/Ent/mask_patches/9315.png
#   inflating: /content/sample_data/Ent/mask_patches/9316.png
#   inflating: /content/sample_data/Ent/mask_patches/9317.png
#   inflating: /content/sample_data/Ent/mask_patches/9318.png
#   inflating: /content/sample_data/Ent/mask_patches/9319.png
#   inflating: /content/sample_data/Ent/mask_patches/932.png
#   inflating: /content/sample_data/Ent/mask_patches/9320.png
#   inflating: /content/sample_data/Ent/mask_patches/9321.png
#   inflating: /content/sample_data/Ent/mask_patches/9322.png
#   inflating: /content/sample_data/Ent/mask_patches/9323.png
#   inflating: /content/sample_data/Ent/mask_patches/9324.png
#   inflating: /content/sample_data/Ent/mask_patches/9325.png
#   inflating: /content/sample_data/Ent/mask_patches/9326.png
#   inflating: /content/sample_data/Ent/mask_patches/9327.png
#   inflating: /content/sample_data/Ent/mask_patches/9328.png
#   inflating: /content/sample_data/Ent/mask_patches/9329.png
#   inflating: /content/sample_data/Ent/mask_patches/933.png
#   inflating: /content/sample_data/Ent/mask_patches/9330.png
#   inflating: /content/sample_data/Ent/mask_patches/9331.png
#   inflating: /content/sample_data/Ent/mask_patches/9332.png
#   inflating: /content/sample_data/Ent/mask_patches/9333.png
#   inflating: /content/sample_data/Ent/mask_patches/9334.png
#   inflating: /content/sample_data/Ent/mask_patches/9335.png
#   inflating: /content/sample_data/Ent/mask_patches/9336.png
#   inflating: /content/sample_data/Ent/mask_patches/9337.png
#   inflating: /content/sample_data/Ent/mask_patches/9338.png
#   inflating: /content/sample_data/Ent/mask_patches/9339.png
#   inflating: /content/sample_data/Ent/mask_patches/934.png
#   inflating: /content/sample_data/Ent/mask_patches/9340.png
#   inflating: /content/sample_data/Ent/mask_patches/9341.png
#   inflating: /content/sample_data/Ent/mask_patches/9342.png
#   inflating: /content/sample_data/Ent/mask_patches/9343.png
#   inflating: /content/sample_data/Ent/mask_patches/9344.png
#   inflating: /content/sample_data/Ent/mask_patches/9345.png
#   inflating: /content/sample_data/Ent/mask_patches/9346.png
#   inflating: /content/sample_data/Ent/mask_patches/9347.png
#   inflating: /content/sample_data/Ent/mask_patches/9348.png
#   inflating: /content/sample_data/Ent/mask_patches/9349.png
#   inflating: /content/sample_data/Ent/mask_patches/935.png
#   inflating: /content/sample_data/Ent/mask_patches/9350.png
#   inflating: /content/sample_data/Ent/mask_patches/9351.png
#   inflating: /content/sample_data/Ent/mask_patches/9352.png
#   inflating: /content/sample_data/Ent/mask_patches/9353.png
#   inflating: /content/sample_data/Ent/mask_patches/9354.png
#   inflating: /content/sample_data/Ent/mask_patches/9355.png
#   inflating: /content/sample_data/Ent/mask_patches/9356.png
#   inflating: /content/sample_data/Ent/mask_patches/9357.png
#   inflating: /content/sample_data/Ent/mask_patches/9358.png
#   inflating: /content/sample_data/Ent/mask_patches/9359.png
#   inflating: /content/sample_data/Ent/mask_patches/936.png
#   inflating: /content/sample_data/Ent/mask_patches/9360.png
#   inflating: /content/sample_data/Ent/mask_patches/9361.png
#   inflating: /content/sample_data/Ent/mask_patches/9362.png
#   inflating: /content/sample_data/Ent/mask_patches/9363.png
#   inflating: /content/sample_data/Ent/mask_patches/9364.png
#   inflating: /content/sample_data/Ent/mask_patches/9365.png
#   inflating: /content/sample_data/Ent/mask_patches/9366.png
#   inflating: /content/sample_data/Ent/mask_patches/9367.png
#   inflating: /content/sample_data/Ent/mask_patches/9368.png
#   inflating: /content/sample_data/Ent/mask_patches/9369.png
#   inflating: /content/sample_data/Ent/mask_patches/937.png
#   inflating: /content/sample_data/Ent/mask_patches/9370.png
#   inflating: /content/sample_data/Ent/mask_patches/9371.png
#   inflating: /content/sample_data/Ent/mask_patches/9372.png
#   inflating: /content/sample_data/Ent/mask_patches/9373.png
#   inflating: /content/sample_data/Ent/mask_patches/9374.png
#   inflating: /content/sample_data/Ent/mask_patches/9375.png
#   inflating: /content/sample_data/Ent/mask_patches/9376.png
#   inflating: /content/sample_data/Ent/mask_patches/9377.png
#   inflating: /content/sample_data/Ent/mask_patches/9378.png
#   inflating: /content/sample_data/Ent/mask_patches/9379.png
#   inflating: /content/sample_data/Ent/mask_patches/938.png
#   inflating: /content/sample_data/Ent/mask_patches/9380.png
#   inflating: /content/sample_data/Ent/mask_patches/9381.png
#   inflating: /content/sample_data/Ent/mask_patches/9382.png
#   inflating: /content/sample_data/Ent/mask_patches/9383.png
#   inflating: /content/sample_data/Ent/mask_patches/9384.png
#   inflating: /content/sample_data/Ent/mask_patches/9385.png
#   inflating: /content/sample_data/Ent/mask_patches/9386.png
#   inflating: /content/sample_data/Ent/mask_patches/9387.png
#   inflating: /content/sample_data/Ent/mask_patches/9388.png
#   inflating: /content/sample_data/Ent/mask_patches/9389.png
#   inflating: /content/sample_data/Ent/mask_patches/939.png
#   inflating: /content/sample_data/Ent/mask_patches/9390.png
#   inflating: /content/sample_data/Ent/mask_patches/9391.png
#   inflating: /content/sample_data/Ent/mask_patches/9392.png
#   inflating: /content/sample_data/Ent/mask_patches/9393.png
#   inflating: /content/sample_data/Ent/mask_patches/9394.png
#   inflating: /content/sample_data/Ent/mask_patches/9395.png
#   inflating: /content/sample_data/Ent/mask_patches/9396.png
#   inflating: /content/sample_data/Ent/mask_patches/9397.png
#   inflating: /content/sample_data/Ent/mask_patches/9398.png
#   inflating: /content/sample_data/Ent/mask_patches/9399.png
#   inflating: /content/sample_data/Ent/mask_patches/94.png
#   inflating: /content/sample_data/Ent/mask_patches/940.png
#   inflating: /content/sample_data/Ent/mask_patches/9400.png
#   inflating: /content/sample_data/Ent/mask_patches/9401.png
#   inflating: /content/sample_data/Ent/mask_patches/9402.png
#   inflating: /content/sample_data/Ent/mask_patches/9403.png
#   inflating: /content/sample_data/Ent/mask_patches/9404.png
#   inflating: /content/sample_data/Ent/mask_patches/9405.png
#   inflating: /content/sample_data/Ent/mask_patches/9406.png
#   inflating: /content/sample_data/Ent/mask_patches/9407.png
#   inflating: /content/sample_data/Ent/mask_patches/9408.png
#   inflating: /content/sample_data/Ent/mask_patches/9409.png
#   inflating: /content/sample_data/Ent/mask_patches/941.png
#   inflating: /content/sample_data/Ent/mask_patches/9410.png
#   inflating: /content/sample_data/Ent/mask_patches/9411.png
#   inflating: /content/sample_data/Ent/mask_patches/9412.png
#   inflating: /content/sample_data/Ent/mask_patches/9413.png
#   inflating: /content/sample_data/Ent/mask_patches/9414.png
#   inflating: /content/sample_data/Ent/mask_patches/9415.png
#   inflating: /content/sample_data/Ent/mask_patches/9416.png
#   inflating: /content/sample_data/Ent/mask_patches/9417.png
#   inflating: /content/sample_data/Ent/mask_patches/9418.png
#   inflating: /content/sample_data/Ent/mask_patches/9419.png
#   inflating: /content/sample_data/Ent/mask_patches/942.png
#   inflating: /content/sample_data/Ent/mask_patches/9420.png
#   inflating: /content/sample_data/Ent/mask_patches/9421.png
#   inflating: /content/sample_data/Ent/mask_patches/9422.png
#   inflating: /content/sample_data/Ent/mask_patches/9423.png
#   inflating: /content/sample_data/Ent/mask_patches/9424.png
#   inflating: /content/sample_data/Ent/mask_patches/9425.png
#   inflating: /content/sample_data/Ent/mask_patches/9426.png
#   inflating: /content/sample_data/Ent/mask_patches/9427.png
#   inflating: /content/sample_data/Ent/mask_patches/9428.png
#   inflating: /content/sample_data/Ent/mask_patches/9429.png
#   inflating: /content/sample_data/Ent/mask_patches/943.png
#   inflating: /content/sample_data/Ent/mask_patches/9430.png
#   inflating: /content/sample_data/Ent/mask_patches/9431.png
#   inflating: /content/sample_data/Ent/mask_patches/9432.png
#   inflating: /content/sample_data/Ent/mask_patches/9433.png
#   inflating: /content/sample_data/Ent/mask_patches/9434.png
#   inflating: /content/sample_data/Ent/mask_patches/9435.png
#   inflating: /content/sample_data/Ent/mask_patches/9436.png
#   inflating: /content/sample_data/Ent/mask_patches/9437.png
#   inflating: /content/sample_data/Ent/mask_patches/9438.png
#   inflating: /content/sample_data/Ent/mask_patches/9439.png
#   inflating: /content/sample_data/Ent/mask_patches/944.png
#   inflating: /content/sample_data/Ent/mask_patches/9440.png
#   inflating: /content/sample_data/Ent/mask_patches/9441.png
#   inflating: /content/sample_data/Ent/mask_patches/9442.png
#   inflating: /content/sample_data/Ent/mask_patches/9443.png
#   inflating: /content/sample_data/Ent/mask_patches/9444.png
#   inflating: /content/sample_data/Ent/mask_patches/9445.png
#   inflating: /content/sample_data/Ent/mask_patches/9446.png
#   inflating: /content/sample_data/Ent/mask_patches/9447.png
#   inflating: /content/sample_data/Ent/mask_patches/9448.png
#   inflating: /content/sample_data/Ent/mask_patches/9449.png
#   inflating: /content/sample_data/Ent/mask_patches/945.png
#   inflating: /content/sample_data/Ent/mask_patches/9450.png
#   inflating: /content/sample_data/Ent/mask_patches/9451.png
#   inflating: /content/sample_data/Ent/mask_patches/9452.png
#   inflating: /content/sample_data/Ent/mask_patches/9453.png
#   inflating: /content/sample_data/Ent/mask_patches/9454.png
#   inflating: /content/sample_data/Ent/mask_patches/9455.png
#   inflating: /content/sample_data/Ent/mask_patches/9456.png
#   inflating: /content/sample_data/Ent/mask_patches/9457.png
#   inflating: /content/sample_data/Ent/mask_patches/9458.png
#   inflating: /content/sample_data/Ent/mask_patches/9459.png
#   inflating: /content/sample_data/Ent/mask_patches/946.png
#   inflating: /content/sample_data/Ent/mask_patches/9460.png
#   inflating: /content/sample_data/Ent/mask_patches/9461.png
#   inflating: /content/sample_data/Ent/mask_patches/9462.png
#   inflating: /content/sample_data/Ent/mask_patches/9463.png
#   inflating: /content/sample_data/Ent/mask_patches/9464.png
#   inflating: /content/sample_data/Ent/mask_patches/9465.png
#   inflating: /content/sample_data/Ent/mask_patches/9466.png
#   inflating: /content/sample_data/Ent/mask_patches/9467.png
#   inflating: /content/sample_data/Ent/mask_patches/9468.png
#   inflating: /content/sample_data/Ent/mask_patches/9469.png
#   inflating: /content/sample_data/Ent/mask_patches/947.png
#   inflating: /content/sample_data/Ent/mask_patches/9470.png
#   inflating: /content/sample_data/Ent/mask_patches/9471.png
#   inflating: /content/sample_data/Ent/mask_patches/9472.png
#   inflating: /content/sample_data/Ent/mask_patches/9473.png
#   inflating: /content/sample_data/Ent/mask_patches/9474.png
#   inflating: /content/sample_data/Ent/mask_patches/9475.png
#   inflating: /content/sample_data/Ent/mask_patches/9476.png
#   inflating: /content/sample_data/Ent/mask_patches/9477.png
#   inflating: /content/sample_data/Ent/mask_patches/9478.png
#   inflating: /content/sample_data/Ent/mask_patches/9479.png
#   inflating: /content/sample_data/Ent/mask_patches/948.png
#   inflating: /content/sample_data/Ent/mask_patches/9480.png
#   inflating: /content/sample_data/Ent/mask_patches/9481.png
#   inflating: /content/sample_data/Ent/mask_patches/9482.png
#   inflating: /content/sample_data/Ent/mask_patches/9483.png
#   inflating: /content/sample_data/Ent/mask_patches/9484.png
#   inflating: /content/sample_data/Ent/mask_patches/9485.png
#   inflating: /content/sample_data/Ent/mask_patches/9486.png
#   inflating: /content/sample_data/Ent/mask_patches/9487.png
#   inflating: /content/sample_data/Ent/mask_patches/9488.png
#   inflating: /content/sample_data/Ent/mask_patches/9489.png
#   inflating: /content/sample_data/Ent/mask_patches/949.png
#   inflating: /content/sample_data/Ent/mask_patches/9490.png
#   inflating: /content/sample_data/Ent/mask_patches/9491.png
#   inflating: /content/sample_data/Ent/mask_patches/9492.png
#   inflating: /content/sample_data/Ent/mask_patches/9493.png
#   inflating: /content/sample_data/Ent/mask_patches/9494.png
#   inflating: /content/sample_data/Ent/mask_patches/9495.png
#   inflating: /content/sample_data/Ent/mask_patches/9496.png
#   inflating: /content/sample_data/Ent/mask_patches/9497.png
#   inflating: /content/sample_data/Ent/mask_patches/9498.png
#   inflating: /content/sample_data/Ent/mask_patches/9499.png
#   inflating: /content/sample_data/Ent/mask_patches/95.png
#   inflating: /content/sample_data/Ent/mask_patches/950.png
#   inflating: /content/sample_data/Ent/mask_patches/9500.png
#   inflating: /content/sample_data/Ent/mask_patches/9501.png
#   inflating: /content/sample_data/Ent/mask_patches/9502.png
#   inflating: /content/sample_data/Ent/mask_patches/9503.png
#   inflating: /content/sample_data/Ent/mask_patches/9504.png
#   inflating: /content/sample_data/Ent/mask_patches/9505.png
#   inflating: /content/sample_data/Ent/mask_patches/9506.png
#   inflating: /content/sample_data/Ent/mask_patches/9507.png
#   inflating: /content/sample_data/Ent/mask_patches/9508.png
#   inflating: /content/sample_data/Ent/mask_patches/9509.png
#   inflating: /content/sample_data/Ent/mask_patches/951.png
#   inflating: /content/sample_data/Ent/mask_patches/9510.png
#   inflating: /content/sample_data/Ent/mask_patches/9511.png
#   inflating: /content/sample_data/Ent/mask_patches/9512.png
#   inflating: /content/sample_data/Ent/mask_patches/9513.png
#   inflating: /content/sample_data/Ent/mask_patches/9514.png
#   inflating: /content/sample_data/Ent/mask_patches/9515.png
#   inflating: /content/sample_data/Ent/mask_patches/9516.png
#   inflating: /content/sample_data/Ent/mask_patches/9517.png
#   inflating: /content/sample_data/Ent/mask_patches/9518.png
#   inflating: /content/sample_data/Ent/mask_patches/9519.png
#   inflating: /content/sample_data/Ent/mask_patches/952.png
#   inflating: /content/sample_data/Ent/mask_patches/9520.png
#   inflating: /content/sample_data/Ent/mask_patches/9521.png
#   inflating: /content/sample_data/Ent/mask_patches/9522.png
#   inflating: /content/sample_data/Ent/mask_patches/9523.png
#   inflating: /content/sample_data/Ent/mask_patches/9524.png
#   inflating: /content/sample_data/Ent/mask_patches/9525.png
#   inflating: /content/sample_data/Ent/mask_patches/9526.png
#   inflating: /content/sample_data/Ent/mask_patches/9527.png
#   inflating: /content/sample_data/Ent/mask_patches/9528.png
#   inflating: /content/sample_data/Ent/mask_patches/9529.png
#   inflating: /content/sample_data/Ent/mask_patches/953.png
#   inflating: /content/sample_data/Ent/mask_patches/9530.png
#   inflating: /content/sample_data/Ent/mask_patches/9531.png
#   inflating: /content/sample_data/Ent/mask_patches/9532.png
#   inflating: /content/sample_data/Ent/mask_patches/9533.png
#   inflating: /content/sample_data/Ent/mask_patches/9534.png
#   inflating: /content/sample_data/Ent/mask_patches/9535.png
#   inflating: /content/sample_data/Ent/mask_patches/9536.png
#   inflating: /content/sample_data/Ent/mask_patches/9537.png
#   inflating: /content/sample_data/Ent/mask_patches/9538.png
#   inflating: /content/sample_data/Ent/mask_patches/9539.png
#   inflating: /content/sample_data/Ent/mask_patches/954.png
#   inflating: /content/sample_data/Ent/mask_patches/9540.png
#   inflating: /content/sample_data/Ent/mask_patches/9541.png
#   inflating: /content/sample_data/Ent/mask_patches/9542.png
#   inflating: /content/sample_data/Ent/mask_patches/9543.png
#   inflating: /content/sample_data/Ent/mask_patches/9544.png
#   inflating: /content/sample_data/Ent/mask_patches/9545.png
#   inflating: /content/sample_data/Ent/mask_patches/9546.png
#   inflating: /content/sample_data/Ent/mask_patches/9547.png
#   inflating: /content/sample_data/Ent/mask_patches/9548.png
#   inflating: /content/sample_data/Ent/mask_patches/9549.png
#   inflating: /content/sample_data/Ent/mask_patches/955.png
#   inflating: /content/sample_data/Ent/mask_patches/9550.png
#   inflating: /content/sample_data/Ent/mask_patches/9551.png
#   inflating: /content/sample_data/Ent/mask_patches/9552.png
#   inflating: /content/sample_data/Ent/mask_patches/9553.png
#   inflating: /content/sample_data/Ent/mask_patches/9554.png
#   inflating: /content/sample_data/Ent/mask_patches/9555.png
#   inflating: /content/sample_data/Ent/mask_patches/9556.png
#   inflating: /content/sample_data/Ent/mask_patches/9557.png
#   inflating: /content/sample_data/Ent/mask_patches/9558.png
#   inflating: /content/sample_data/Ent/mask_patches/9559.png
#   inflating: /content/sample_data/Ent/mask_patches/956.png
#   inflating: /content/sample_data/Ent/mask_patches/9560.png
#   inflating: /content/sample_data/Ent/mask_patches/9561.png
#   inflating: /content/sample_data/Ent/mask_patches/9562.png
#   inflating: /content/sample_data/Ent/mask_patches/9563.png
#   inflating: /content/sample_data/Ent/mask_patches/9564.png
#   inflating: /content/sample_data/Ent/mask_patches/9565.png
#   inflating: /content/sample_data/Ent/mask_patches/9566.png
#   inflating: /content/sample_data/Ent/mask_patches/9567.png
#   inflating: /content/sample_data/Ent/mask_patches/9568.png
#   inflating: /content/sample_data/Ent/mask_patches/9569.png
#   inflating: /content/sample_data/Ent/mask_patches/957.png
#   inflating: /content/sample_data/Ent/mask_patches/9570.png
#   inflating: /content/sample_data/Ent/mask_patches/9571.png
#   inflating: /content/sample_data/Ent/mask_patches/9572.png
#   inflating: /content/sample_data/Ent/mask_patches/9573.png
#   inflating: /content/sample_data/Ent/mask_patches/9574.png
#   inflating: /content/sample_data/Ent/mask_patches/9575.png
#   inflating: /content/sample_data/Ent/mask_patches/9576.png
#   inflating: /content/sample_data/Ent/mask_patches/9577.png
#   inflating: /content/sample_data/Ent/mask_patches/9578.png
#   inflating: /content/sample_data/Ent/mask_patches/9579.png
#   inflating: /content/sample_data/Ent/mask_patches/958.png
#   inflating: /content/sample_data/Ent/mask_patches/9580.png
#   inflating: /content/sample_data/Ent/mask_patches/9581.png
#   inflating: /content/sample_data/Ent/mask_patches/9582.png
#   inflating: /content/sample_data/Ent/mask_patches/9583.png
#   inflating: /content/sample_data/Ent/mask_patches/9584.png
#   inflating: /content/sample_data/Ent/mask_patches/9585.png
#   inflating: /content/sample_data/Ent/mask_patches/9586.png
#   inflating: /content/sample_data/Ent/mask_patches/9587.png
#   inflating: /content/sample_data/Ent/mask_patches/9588.png
#   inflating: /content/sample_data/Ent/mask_patches/9589.png
#   inflating: /content/sample_data/Ent/mask_patches/959.png
#   inflating: /content/sample_data/Ent/mask_patches/9590.png
#   inflating: /content/sample_data/Ent/mask_patches/9591.png
#   inflating: /content/sample_data/Ent/mask_patches/9592.png
#   inflating: /content/sample_data/Ent/mask_patches/9593.png
#   inflating: /content/sample_data/Ent/mask_patches/9594.png
#   inflating: /content/sample_data/Ent/mask_patches/9595.png
#   inflating: /content/sample_data/Ent/mask_patches/9596.png
#   inflating: /content/sample_data/Ent/mask_patches/9597.png
#   inflating: /content/sample_data/Ent/mask_patches/9598.png
#   inflating: /content/sample_data/Ent/mask_patches/9599.png
#   inflating: /content/sample_data/Ent/mask_patches/96.png
#   inflating: /content/sample_data/Ent/mask_patches/960.png
#   inflating: /content/sample_data/Ent/mask_patches/9600.png
#   inflating: /content/sample_data/Ent/mask_patches/9601.png
#   inflating: /content/sample_data/Ent/mask_patches/9602.png
#   inflating: /content/sample_data/Ent/mask_patches/9603.png
#   inflating: /content/sample_data/Ent/mask_patches/9604.png
#   inflating: /content/sample_data/Ent/mask_patches/9605.png
#   inflating: /content/sample_data/Ent/mask_patches/9606.png
#   inflating: /content/sample_data/Ent/mask_patches/9607.png
#   inflating: /content/sample_data/Ent/mask_patches/9608.png
#   inflating: /content/sample_data/Ent/mask_patches/9609.png
#   inflating: /content/sample_data/Ent/mask_patches/961.png
#   inflating: /content/sample_data/Ent/mask_patches/9610.png
#   inflating: /content/sample_data/Ent/mask_patches/9611.png
#   inflating: /content/sample_data/Ent/mask_patches/9612.png
#   inflating: /content/sample_data/Ent/mask_patches/9613.png
#   inflating: /content/sample_data/Ent/mask_patches/9614.png
#   inflating: /content/sample_data/Ent/mask_patches/9615.png
#   inflating: /content/sample_data/Ent/mask_patches/9616.png
#   inflating: /content/sample_data/Ent/mask_patches/9617.png
#   inflating: /content/sample_data/Ent/mask_patches/9618.png
#   inflating: /content/sample_data/Ent/mask_patches/9619.png
#   inflating: /content/sample_data/Ent/mask_patches/962.png
#   inflating: /content/sample_data/Ent/mask_patches/9620.png
#   inflating: /content/sample_data/Ent/mask_patches/9621.png
#   inflating: /content/sample_data/Ent/mask_patches/9622.png
#   inflating: /content/sample_data/Ent/mask_patches/9623.png
#   inflating: /content/sample_data/Ent/mask_patches/9624.png
#   inflating: /content/sample_data/Ent/mask_patches/9625.png
#   inflating: /content/sample_data/Ent/mask_patches/9626.png
#   inflating: /content/sample_data/Ent/mask_patches/9627.png
#   inflating: /content/sample_data/Ent/mask_patches/9628.png
#   inflating: /content/sample_data/Ent/mask_patches/9629.png
#   inflating: /content/sample_data/Ent/mask_patches/963.png
#   inflating: /content/sample_data/Ent/mask_patches/9630.png
#   inflating: /content/sample_data/Ent/mask_patches/9631.png
#   inflating: /content/sample_data/Ent/mask_patches/9632.png
#   inflating: /content/sample_data/Ent/mask_patches/9633.png
#   inflating: /content/sample_data/Ent/mask_patches/9634.png
#   inflating: /content/sample_data/Ent/mask_patches/9635.png
#   inflating: /content/sample_data/Ent/mask_patches/9636.png
# ...
#   inflating: /content/sample_data/Val/mask_patches/763.png
#   inflating: /content/sample_data/Val/mask_patches/764.png
#   inflating: /content/sample_data/Val/mask_patches/765.png
#   inflating: /content/sample_data/Val/mask_patches/766.png
#   inflating: /content/sample_data/Val/mask_patches/767.png
#   inflating: /content/sample_data/Val/mask_patches/768.png
#   inflating: /content/sample_data/Val/mask_patches/769.png
#   inflating: /content/sample_data/Val/mask_patches/77.png
#   inflating: /content/sample_data/Val/mask_patches/770.png
#   inflating: /content/sample_data/Val/mask_patches/771.png
#   inflating: /content/sample_data/Val/mask_patches/772.png
#   inflating: /content/sample_data/Val/mask_patches/773.png
#   inflating: /content/sample_data/Val/mask_patches/774.png
#   inflating: /content/sample_data/Val/mask_patches/775.png
#   inflating: /content/sample_data/Val/mask_patches/776.png
#   inflating: /content/sample_data/Val/mask_patches/777.png
#   inflating: /content/sample_data/Val/mask_patches/778.png
#   inflating: /content/sample_data/Val/mask_patches/779.png
#   inflating: /content/sample_data/Val/mask_patches/78.png
#   inflating: /content/sample_data/Val/mask_patches/780.png
#   inflating: /content/sample_data/Val/mask_patches/781.png
#   inflating: /content/sample_data/Val/mask_patches/782.png
#   inflating: /content/sample_data/Val/mask_patches/783.png
#   inflating: /content/sample_data/Val/mask_patches/784.png
#   inflating: /content/sample_data/Val/mask_patches/785.png
#   inflating: /content/sample_data/Val/mask_patches/786.png
#   inflating: /content/sample_data/Val/mask_patches/787.png
#   inflating: /content/sample_data/Val/mask_patches/788.png
#   inflating: /content/sample_data/Val/mask_patches/789.png
#   inflating: /content/sample_data/Val/mask_patches/79.png
#   inflating: /content/sample_data/Val/mask_patches/790.png
#   inflating: /content/sample_data/Val/mask_patches/791.png
#   inflating: /content/sample_data/Val/mask_patches/792.png
#   inflating: /content/sample_data/Val/mask_patches/793.png
#   inflating: /content/sample_data/Val/mask_patches/794.png
#   inflating: /content/sample_data/Val/mask_patches/795.png
#   inflating: /content/sample_data/Val/mask_patches/796.png
#   inflating: /content/sample_data/Val/mask_patches/797.png
#   inflating: /content/sample_data/Val/mask_patches/798.png
#   inflating: /content/sample_data/Val/mask_patches/799.png
#   inflating: /content/sample_data/Val/mask_patches/8.png
#   inflating: /content/sample_data/Val/mask_patches/80.png
#   inflating: /content/sample_data/Val/mask_patches/800.png
#   inflating: /content/sample_data/Val/mask_patches/801.png
#   inflating: /content/sample_data/Val/mask_patches/802.png
#   inflating: /content/sample_data/Val/mask_patches/803.png
#   inflating: /content/sample_data/Val/mask_patches/804.png
#   inflating: /content/sample_data/Val/mask_patches/805.png
#   inflating: /content/sample_data/Val/mask_patches/806.png
#   inflating: /content/sample_data/Val/mask_patches/807.png
#   inflating: /content/sample_data/Val/mask_patches/808.png
#   inflating: /content/sample_data/Val/mask_patches/809.png
#   inflating: /content/sample_data/Val/mask_patches/81.png
#   inflating: /content/sample_data/Val/mask_patches/810.png
#   inflating: /content/sample_data/Val/mask_patches/811.png
#   inflating: /content/sample_data/Val/mask_patches/812.png
#   inflating: /content/sample_data/Val/mask_patches/813.png
#   inflating: /content/sample_data/Val/mask_patches/814.png
#   inflating: /content/sample_data/Val/mask_patches/815.png
#   inflating: /content/sample_data/Val/mask_patches/816.png
#   inflating: /content/sample_data/Val/mask_patches/817.png
#   inflating: /content/sample_data/Val/mask_patches/818.png
#   inflating: /content/sample_data/Val/mask_patches/819.png
#   inflating: /content/sample_data/Val/mask_patches/82.png
#   inflating: /content/sample_data/Val/mask_patches/820.png
#   inflating: /content/sample_data/Val/mask_patches/821.png
#   inflating: /content/sample_data/Val/mask_patches/822.png
#   inflating: /content/sample_data/Val/mask_patches/823.png
#   inflating: /content/sample_data/Val/mask_patches/824.png
#   inflating: /content/sample_data/Val/mask_patches/825.png
#   inflating: /content/sample_data/Val/mask_patches/826.png
#   inflating: /content/sample_data/Val/mask_patches/827.png
#   inflating: /content/sample_data/Val/mask_patches/828.png
#   inflating: /content/sample_data/Val/mask_patches/829.png
#   inflating: /content/sample_data/Val/mask_patches/83.png
#   inflating: /content/sample_data/Val/mask_patches/830.png
#   inflating: /content/sample_data/Val/mask_patches/831.png
#   inflating: /content/sample_data/Val/mask_patches/832.png
#   inflating: /content/sample_data/Val/mask_patches/833.png
#   inflating: /content/sample_data/Val/mask_patches/834.png
#   inflating: /content/sample_data/Val/mask_patches/835.png
#   inflating: /content/sample_data/Val/mask_patches/836.png
#   inflating: /content/sample_data/Val/mask_patches/837.png
#   inflating: /content/sample_data/Val/mask_patches/838.png
#   inflating: /content/sample_data/Val/mask_patches/839.png
#   inflating: /content/sample_data/Val/mask_patches/84.png
#   inflating: /content/sample_data/Val/mask_patches/840.png
#   inflating: /content/sample_data/Val/mask_patches/841.png
#   inflating: /content/sample_data/Val/mask_patches/842.png
#   inflating: /content/sample_data/Val/mask_patches/843.png
#   inflating: /content/sample_data/Val/mask_patches/844.png
#   inflating: /content/sample_data/Val/mask_patches/845.png
#   inflating: /content/sample_data/Val/mask_patches/846.png
#   inflating: /content/sample_data/Val/mask_patches/847.png
#   inflating: /content/sample_data/Val/mask_patches/848.png
#   inflating: /content/sample_data/Val/mask_patches/849.png
#   inflating: /content/sample_data/Val/mask_patches/85.png
#   inflating: /content/sample_data/Val/mask_patches/850.png
#   inflating: /content/sample_data/Val/mask_patches/851.png
#   inflating: /content/sample_data/Val/mask_patches/852.png
#   inflating: /content/sample_data/Val/mask_patches/853.png
#   inflating: /content/sample_data/Val/mask_patches/854.png
#   inflating: /content/sample_data/Val/mask_patches/855.png
#   inflating: /content/sample_data/Val/mask_patches/856.png
#   inflating: /content/sample_data/Val/mask_patches/857.png
#   inflating: /content/sample_data/Val/mask_patches/858.png
#   inflating: /content/sample_data/Val/mask_patches/859.png
#   inflating: /content/sample_data/Val/mask_patches/86.png
#   inflating: /content/sample_data/Val/mask_patches/860.png
#   inflating: /content/sample_data/Val/mask_patches/861.png
#   inflating: /content/sample_data/Val/mask_patches/862.png
#   inflating: /content/sample_data/Val/mask_patches/863.png
#   inflating: /content/sample_data/Val/mask_patches/864.png
#   inflating: /content/sample_data/Val/mask_patches/865.png
#   inflating: /content/sample_data/Val/mask_patches/866.png
#   inflating: /content/sample_data/Val/mask_patches/867.png
#   inflating: /content/sample_data/Val/mask_patches/868.png
#   inflating: /content/sample_data/Val/mask_patches/869.png
#   inflating: /content/sample_data/Val/mask_patches/87.png
#   inflating: /content/sample_data/Val/mask_patches/870.png
#   inflating: /content/sample_data/Val/mask_patches/871.png
#   inflating: /content/sample_data/Val/mask_patches/872.png
#   inflating: /content/sample_data/Val/mask_patches/873.png
#   inflating: /content/sample_data/Val/mask_patches/874.png
#   inflating: /content/sample_data/Val/mask_patches/875.png
#   inflating: /content/sample_data/Val/mask_patches/876.png
#   inflating: /content/sample_data/Val/mask_patches/877.png
#   inflating: /content/sample_data/Val/mask_patches/878.png
#   inflating: /content/sample_data/Val/mask_patches/879.png
#   inflating: /content/sample_data/Val/mask_patches/88.png
#   inflating: /content/sample_data/Val/mask_patches/880.png
#   inflating: /content/sample_data/Val/mask_patches/881.png
#   inflating: /content/sample_data/Val/mask_patches/882.png
#   inflating: /content/sample_data/Val/mask_patches/883.png
#   inflating: /content/sample_data/Val/mask_patches/884.png
#   inflating: /content/sample_data/Val/mask_patches/885.png
#   inflating: /content/sample_data/Val/mask_patches/886.png
#   inflating: /content/sample_data/Val/mask_patches/887.png
#   inflating: /content/sample_data/Val/mask_patches/888.png
#   inflating: /content/sample_data/Val/mask_patches/889.png
#   inflating: /content/sample_data/Val/mask_patches/89.png
#   inflating: /content/sample_data/Val/mask_patches/890.png
#   inflating: /content/sample_data/Val/mask_patches/891.png
#   inflating: /content/sample_data/Val/mask_patches/892.png
#   inflating: /content/sample_data/Val/mask_patches/893.png
#   inflating: /content/sample_data/Val/mask_patches/894.png
#   inflating: /content/sample_data/Val/mask_patches/895.png
#   inflating: /content/sample_data/Val/mask_patches/896.png
#   inflating: /content/sample_data/Val/mask_patches/897.png
#   inflating: /content/sample_data/Val/mask_patches/898.png
#   inflating: /content/sample_data/Val/mask_patches/899.png
#   inflating: /content/sample_data/Val/mask_patches/9.png
#   inflating: /content/sample_data/Val/mask_patches/90.png
#   inflating: /content/sample_data/Val/mask_patches/900.png
#   inflating: /content/sample_data/Val/mask_patches/901.png
#   inflating: /content/sample_data/Val/mask_patches/902.png
#   inflating: /content/sample_data/Val/mask_patches/903.png
#   inflating: /content/sample_data/Val/mask_patches/904.png
#   inflating: /content/sample_data/Val/mask_patches/905.png
#   inflating: /content/sample_data/Val/mask_patches/906.png
#   inflating: /content/sample_data/Val/mask_patches/907.png
#   inflating: /content/sample_data/Val/mask_patches/908.png
#   inflating: /content/sample_data/Val/mask_patches/909.png
#   inflating: /content/sample_data/Val/mask_patches/91.png
#   inflating: /content/sample_data/Val/mask_patches/910.png
#   inflating: /content/sample_data/Val/mask_patches/911.png
#   inflating: /content/sample_data/Val/mask_patches/912.png
#   inflating: /content/sample_data/Val/mask_patches/913.png
#   inflating: /content/sample_data/Val/mask_patches/914.png
#   inflating: /content/sample_data/Val/mask_patches/915.png
#   inflating: /content/sample_data/Val/mask_patches/916.png
#   inflating: /content/sample_data/Val/mask_patches/917.png
#   inflating: /content/sample_data/Val/mask_patches/918.png
#   inflating: /content/sample_data/Val/mask_patches/919.png
#   inflating: /content/sample_data/Val/mask_patches/92.png
#   inflating: /content/sample_data/Val/mask_patches/920.png
#   inflating: /content/sample_data/Val/mask_patches/921.png
#   inflating: /content/sample_data/Val/mask_patches/922.png
#   inflating: /content/sample_data/Val/mask_patches/923.png
#   inflating: /content/sample_data/Val/mask_patches/924.png
#   inflating: /content/sample_data/Val/mask_patches/925.png
#   inflating: /content/sample_data/Val/mask_patches/926.png
#   inflating: /content/sample_data/Val/mask_patches/927.png
#   inflating: /content/sample_data/Val/mask_patches/928.png
#   inflating: /content/sample_data/Val/mask_patches/929.png
#   inflating: /content/sample_data/Val/mask_patches/93.png
#   inflating: /content/sample_data/Val/mask_patches/930.png
#   inflating: /content/sample_data/Val/mask_patches/931.png
#   inflating: /content/sample_data/Val/mask_patches/932.png
#   inflating: /content/sample_data/Val/mask_patches/933.png
#   inflating: /content/sample_data/Val/mask_patches/934.png
#   inflating: /content/sample_data/Val/mask_patches/935.png
#   inflating: /content/sample_data/Val/mask_patches/936.png
#   inflating: /content/sample_data/Val/mask_patches/937.png
#   inflating: /content/sample_data/Val/mask_patches/938.png
#   inflating: /content/sample_data/Val/mask_patches/939.png
#   inflating: /content/sample_data/Val/mask_patches/94.png
#   inflating: /content/sample_data/Val/mask_patches/940.png
#   inflating: /content/sample_data/Val/mask_patches/941.png
#   inflating: /content/sample_data/Val/mask_patches/942.png
#   inflating: /content/sample_data/Val/mask_patches/943.png
#   inflating: /content/sample_data/Val/mask_patches/944.png
#   inflating: /content/sample_data/Val/mask_patches/945.png
#   inflating: /content/sample_data/Val/mask_patches/946.png
#   inflating: /content/sample_data/Val/mask_patches/947.png
#   inflating: /content/sample_data/Val/mask_patches/948.png
#   inflating: /content/sample_data/Val/mask_patches/949.png
#   inflating: /content/sample_data/Val/mask_patches/95.png
#   inflating: /content/sample_data/Val/mask_patches/950.png
#   inflating: /content/sample_data/Val/mask_patches/951.png
#   inflating: /content/sample_data/Val/mask_patches/952.png
#   inflating: /content/sample_data/Val/mask_patches/953.png
#   inflating: /content/sample_data/Val/mask_patches/954.png
#   inflating: /content/sample_data/Val/mask_patches/955.png
#   inflating: /content/sample_data/Val/mask_patches/956.png
#   inflating: /content/sample_data/Val/mask_patches/957.png
#   inflating: /content/sample_data/Val/mask_patches/958.png
#   inflating: /content/sample_data/Val/mask_patches/959.png
#   inflating: /content/sample_data/Val/mask_patches/96.png
#   inflating: /content/sample_data/Val/mask_patches/960.png
#   inflating: /content/sample_data/Val/mask_patches/961.png
#   inflating: /content/sample_data/Val/mask_patches/962.png
#   inflating: /content/sample_data/Val/mask_patches/963.png
#   inflating: /content/sample_data/Val/mask_patches/964.png
#   inflating: /content/sample_data/Val/mask_patches/965.png
#   inflating: /content/sample_data/Val/mask_patches/966.png
#   inflating: /content/sample_data/Val/mask_patches/967.png
#   inflating: /content/sample_data/Val/mask_patches/968.png
#   inflating: /content/sample_data/Val/mask_patches/969.png
#   inflating: /content/sample_data/Val/mask_patches/97.png
#   inflating: /content/sample_data/Val/mask_patches/970.png
#   inflating: /content/sample_data/Val/mask_patches/971.png
#   inflating: /content/sample_data/Val/mask_patches/972.png
#   inflating: /content/sample_data/Val/mask_patches/973.png
#   inflating: /content/sample_data/Val/mask_patches/974.png
#   inflating: /content/sample_data/Val/mask_patches/975.png
#   inflating: /content/sample_data/Val/mask_patches/976.png
#   inflating: /content/sample_data/Val/mask_patches/977.png
#   inflating: /content/sample_data/Val/mask_patches/978.png
#   inflating: /content/sample_data/Val/mask_patches/979.png
#   inflating: /content/sample_data/Val/mask_patches/98.png
#   inflating: /content/sample_data/Val/mask_patches/980.png
#   inflating: /content/sample_data/Val/mask_patches/981.png
#   inflating: /content/sample_data/Val/mask_patches/982.png
#   inflating: /content/sample_data/Val/mask_patches/983.png
#   inflating: /content/sample_data/Val/mask_patches/984.png
#   inflating: /content/sample_data/Val/mask_patches/985.png
#   inflating: /content/sample_data/Val/mask_patches/986.png
#   inflating: /content/sample_data/Val/mask_patches/987.png
#   inflating: /content/sample_data/Val/mask_patches/988.png
#   inflating: /content/sample_data/Val/mask_patches/989.png
#   inflating: /content/sample_data/Val/mask_patches/99.png
#   inflating: /content/sample_data/Val/mask_patches/990.png
#   inflating: /content/sample_data/Val/mask_patches/991.png
#   inflating: /content/sample_data/Val/mask_patches/992.png
#   inflating: /content/sample_data/Val/mask_patches/993.png
#   inflating: /content/sample_data/Val/mask_patches/994.png
#   inflating: /content/sample_data/Val/mask_patches/995.png
#   inflating: /content/sample_data/Val/mask_patches/996.png
#   inflating: /content/sample_data/Val/mask_patches/997.png
#   inflating: /content/sample_data/Val/mask_patches/998.png
#   inflating: /content/sample_data/Val/mask_patches/999.png

# %%
ent_input_dir= "/content/sample_data/Ent/img_patches"
ent_target_dir= "/content/sample_data/Ent/mask_patches"

val_input_dir= "/content/sample_data/Val/img_patches"
val_target_dir= "/content/sample_data/Val/mask_patches"

input_img_paths = sorted(
    [
        os.path.join(ent_input_dir, fname)
        for fname in os.listdir(ent_input_dir) 
        if fname.endswith(".png")
    ]
)

target_img_paths = sorted(
    [
        os.path.join(ent_target_dir, fname)
        for fname in os.listdir(ent_target_dir)
        if fname.endswith(".png") and not fname.startswith(".")
    ]
)

val_input_paths = sorted(
    [
        os.path.join(val_input_dir, fname)
        for fname in os.listdir(val_input_dir)
        if fname.endswith(".png") and not fname.startswith(".")
    ]
)

val_target_paths = sorted(
    [
        os.path.join(val_target_dir, fname)
        for fname in os.listdir(val_target_dir)
        if fname.endswith(".png") and not fname.startswith(".")
    ]
)

no_ent= len(input_img_paths)
no_val= len(val_target_paths)

# %%
class MiClasificacion():
    def __init__(self, No_img, cont= 0, batch_size= 32, img_size= (304, 304)):
        self.batch_size= batch_size
        self.img_size= img_size
        self.cont= cont
        self.steps= No_img// self.batch_size
        self.ID_input= np.arange(No_img)

    def dar_datos(self, img_dir, val_dir):
        if self.steps== self.cont or self.cont== 0:
            np.random.shuffle(self.ID_input)
            self.cont= 0
        
        batch_img= []
        batch_tar= []
        i= self.cont* self.batch_size
        self.cont+= 1

        x = np.zeros((self.batch_size,) + self.img_size + (3,), dtype="float32")
        y = np.zeros((self.batch_size,) + self.img_size + (1,), dtype="uint8") 


        for ig in self.ID_input[i : i + self.batch_size]:
            batch_img.append(img_dir[ig])
            batch_tar.append(val_dir[ig])


        for j, path in enumerate(batch_img):
                img = load_img(path, target_size= self.img_size)
                x[j] = np.array(img)/255.0  

        for j, path in enumerate(batch_tar):
                img = load_img(path,target_size= self.img_size, color_mode="grayscale")
                y[j] = np.expand_dims(img, 2)
                
                for r in range(y.shape[1]):
                    for g in range(y.shape[2]):
                        if y[j, r, g, 0]!= 0:
                            y[j, r, g, 0]= 1
    
        return x, y

# %%
img_size = (320, 320)
num_classes = 2; batch_size_t = 16; batch_size_v = 16

train_gen = MiClasificacion(no_ent, batch_size= batch_size_t, img_size= img_size)
val_gen = MiClasificacion(no_val, batch_size=batch_size_v, img_size= img_size)

# %%
optimizer= tf.keras.optimizers.Adam()
loss_fn= tf.keras.losses.SparseCategoricalCrossentropy(from_logits= False)

train_loss= tf.keras.metrics.Mean(name= 'train_loss')
train_accuracy= tf.keras.metrics.SparseCategoricalAccuracy(name= 'train_accuracy')
train_recall= tf.keras.metrics.Recall(name= 'train_recall')
train_precision= tf.keras.metrics.Precision(name= 'train_precision')


test_loss= tf.keras.metrics.Mean(name= 'test_loss')
test_accuracy= tf.keras.metrics.SparseCategoricalAccuracy(name= 'test_accuracy')
test_recall= tf.keras.metrics.Recall(name= 'test_recall')
test_precision= tf.keras.metrics.Precision(name= 'test_precision')


current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
train_log_dir = '/content/drive/MyDrive/Kika/Modelos guardados/Metricas/' + current_time + '/train'
test_log_dir = '/content/drive/MyDrive/Kika/Modelos guardados/Metricas/' + current_time + '/test'

train_summary_writer = tf.summary.create_file_writer(train_log_dir)
test_summary_writer = tf.summary.create_file_writer(test_log_dir)

# %%
@tf.function
def train_step(x, y, y_n):
    
    with tf.GradientTape() as tape:
        predict= mi_modelo(x, training= True)
        loss= loss_fn(y, predict)

    grads= tape.gradient(loss, mi_modelo.trainable_variables)
    optimizer.apply_gradients(zip(grads, mi_modelo.trainable_variables))

    train_loss(loss)
    train_accuracy(y, predict)
    train_recall(y_n, predict)
    train_precision(y_n, predict)

@tf.function
def test_step(x, y, y_n):
    
    predictions= mi_modelo(x, training= False)
    loss= loss_fn(y, predictions)

    test_loss(loss)
    test_accuracy(y, predictions)
    test_recall(y_n, predictions)
    test_precision(y_n, predictions)

# %%
epocas= 150
loss_best= 1500

for epoca in range(epocas):
  train_loss.reset_states()
  train_accuracy.reset_states()
  train_recall.reset_states()
  train_precision.reset_states()

  test_loss.reset_state()
  test_accuracy.reset_state()
  test_recall.reset_states()
  test_precision.reset_states()

  for t in range(int(no_ent/batch_size_t)):
    images, labels= train_gen.dar_datos(input_img_paths, target_img_paths)
    y= tf.keras.utils.to_categorical(labels, num_classes= 2)
    train_step(images, labels, y)
  with train_summary_writer.as_default():
    tf.summary.scalar('Loss', train_loss.result(), step=epoca)
    tf.summary.scalar('Accuracy', train_accuracy.result(), step=epoca)
    tf.summary.scalar('Recall', train_recall.result(), step=epoca)
    tf.summary.scalar('Presicion', train_precision.result(), step=epoca)        

  for t in range(int(no_val/batch_size_t)):
    test_im, test_label= val_gen.dar_datos(val_input_paths, val_target_paths)
    y= tf.keras.utils.to_categorical(test_label, num_classes= 2)
    test_step(test_im, test_label, y)
  with test_summary_writer.as_default():
    tf.summary.scalar('Loss_t', test_loss.result(), step=epoca)
    tf.summary.scalar('Accuracy_t', test_accuracy.result(), step=epoca)
    tf.summary.scalar('Recall_t', test_recall.result(), step=epoca)
    tf.summary.scalar('Presicion_t', test_precision.result(), step=epoca) 
  
  if test_loss.result() < loss_best:
    loss_best= test_loss.result()/1
    mi_modelo.save_weights('/content/drive/MyDrive/Kika/Modelos guardados/Modelos/UNET-CBAM/UNET-CBAM')
    mi_modelo.save('/content/drive/MyDrive/Kika/Modelos guardados/Modelos/UNET-CBAM/UNET-CBAM.h5py')

  print('-------------------------------------------------\n')
  print(
      f'Epoca {epoca+ 1}, '
      f'Loss: {train_loss.result():.3f}, '
      f'Accuracy: {train_accuracy.result()* 100:.3f}, '
      f'Recall: {train_recall.result()* 100:.3f}, '
      f'Precision: {train_precision.result()* 100:.3f} '
      )
      
  print(
      f'Loss_test: {test_loss.result():.3f}, '
      f'Accuracy_test: {test_accuracy.result()* 100:.3f}, '
      f'Recall_test: {test_recall.result()* 100:.3f}, '
      f'Precision_test: {test_precision.result()* 100:.3f} '
  )
  print('\n-------------------------------------------------')
# Out:
# WARNING:absl:Found untraced functions such as dense_layer_call_fn, dense_layer_call_and_return_conditional_losses, dense_1_layer_call_fn, dense_1_layer_call_and_return_conditional_losses, dense_2_layer_call_fn while saving (showing 5 of 285). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Kika/Modelos guardados/Modelos/UNET-CBAM/UNET-CBAM.h5py/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Kika/Modelos guardados/Modelos/UNET-CBAM/UNET-CBAM.h5py/assets
# -------------------------------------------------
#
# Epoca 1, Loss: 0.134, Accuracy: 95.403, Recall: 95.403, Precision: 95.403
# Loss_test: 0.153, Accuracy_test: 94.421, Recall_test: 94.421, Precision_test: 94.421
#
# -------------------------------------------------
# WARNING:absl:Found untraced functions such as dense_layer_call_fn, dense_layer_call_and_return_conditional_losses, dense_1_layer_call_fn, dense_1_layer_call_and_return_conditional_losses, dense_2_layer_call_fn while saving (showing 5 of 285). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Kika/Modelos guardados/Modelos/UNET-CBAM/UNET-CBAM.h5py/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Kika/Modelos guardados/Modelos/UNET-CBAM/UNET-CBAM.h5py/assets
# -------------------------------------------------
#
# Epoca 2, Loss: 0.092, Accuracy: 96.561, Recall: 96.561, Precision: 96.561
# Loss_test: 0.099, Accuracy_test: 96.521, Recall_test: 96.521, Precision_test: 96.521
#
# -------------------------------------------------
# WARNING:absl:Found untraced functions such as dense_layer_call_fn, dense_layer_call_and_return_conditional_losses, dense_1_layer_call_fn, dense_1_layer_call_and_return_conditional_losses, dense_2_layer_call_fn while saving (showing 5 of 285). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Kika/Modelos guardados/Modelos/UNET-CBAM/UNET-CBAM.h5py/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Kika/Modelos guardados/Modelos/UNET-CBAM/UNET-CBAM.h5py/assets
# -------------------------------------------------
#
# Epoca 3, Loss: 0.087, Accuracy: 96.703, Recall: 96.703, Precision: 96.703
# Loss_test: 0.087, Accuracy_test: 96.785, Recall_test: 96.784, Precision_test: 96.784
#
# -------------------------------------------------
# WARNING:absl:Found untraced functions such as dense_layer_call_fn, dense_layer_call_and_return_conditional_losses, dense_1_layer_call_fn, dense_1_layer_call_and_return_conditional_losses, dense_2_layer_call_fn while saving (showing 5 of 285). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Kika/Modelos guardados/Modelos/UNET-CBAM/UNET-CBAM.h5py/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Kika/Modelos guardados/Modelos/UNET-CBAM/UNET-CBAM.h5py/assets
# -------------------------------------------------
#
# Epoca 4, Loss: 0.084, Accuracy: 96.769, Recall: 96.769, Precision: 96.769
# Loss_test: 0.084, Accuracy_test: 96.815, Recall_test: 96.815, Precision_test: 96.815
#
# -------------------------------------------------
# WARNING:absl:Found untraced functions such as dense_layer_call_fn, dense_layer_call_and_return_conditional_losses, dense_1_layer_call_fn, dense_1_layer_call_and_return_conditional_losses, dense_2_layer_call_fn while saving (showing 5 of 285). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Kika/Modelos guardados/Modelos/UNET-CBAM/UNET-CBAM.h5py/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Kika/Modelos guardados/Modelos/UNET-CBAM/UNET-CBAM.h5py/assets
# -------------------------------------------------
#
# Epoca 5, Loss: 0.083, Accuracy: 96.822, Recall: 96.822, Precision: 96.822
# Loss_test: 0.083, Accuracy_test: 96.960, Recall_test: 96.960, Precision_test: 96.960
#
# -------------------------------------------------
# -------------------------------------------------
#
# Epoca 6, Loss: 0.081, Accuracy: 96.876, Recall: 96.876, Precision: 96.876
# Loss_test: 0.093, Accuracy_test: 96.726, Recall_test: 96.726, Precision_test: 96.726
#
# -------------------------------------------------
# WARNING:absl:Found untraced functions such as dense_layer_call_fn, dense_layer_call_and_return_conditional_losses, dense_1_layer_call_fn, dense_1_layer_call_and_return_conditional_losses, dense_2_layer_call_fn while saving (showing 5 of 285). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Kika/Modelos guardados/Modelos/UNET-CBAM/UNET-CBAM.h5py/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Kika/Modelos guardados/Modelos/UNET-CBAM/UNET-CBAM.h5py/assets
# -------------------------------------------------
#
# Epoca 7, Loss: 0.080, Accuracy: 96.905, Recall: 96.905, Precision: 96.905
# Loss_test: 0.078, Accuracy_test: 96.977, Recall_test: 96.977, Precision_test: 96.977
#
# -------------------------------------------------
# -------------------------------------------------
#
# Epoca 8, Loss: 0.079, Accuracy: 96.922, Recall: 96.922, Precision: 96.922
# Loss_test: 0.079, Accuracy_test: 96.971, Recall_test: 96.971, Precision_test: 96.971
#
# -------------------------------------------------
# -------------------------------------------------
#
# Epoca 9, Loss: 0.078, Accuracy: 96.951, Recall: 96.951, Precision: 96.951
# Loss_test: 0.081, Accuracy_test: 96.895, Recall_test: 96.895, Precision_test: 96.895
#
# -------------------------------------------------
# WARNING:absl:Found untraced functions such as dense_layer_call_fn, dense_layer_call_and_return_conditional_losses, dense_1_layer_call_fn, dense_1_layer_call_and_return_conditional_losses, dense_2_layer_call_fn while saving (showing 5 of 285). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Kika/Modelos guardados/Modelos/UNET-CBAM/UNET-CBAM.h5py/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Kika/Modelos guardados/Modelos/UNET-CBAM/UNET-CBAM.h5py/assets
# -------------------------------------------------
#
# Epoca 10, Loss: 0.078, Accuracy: 96.962, Recall: 96.962, Precision: 96.962
# Loss_test: 0.078, Accuracy_test: 96.947, Recall_test: 96.947, Precision_test: 96.947
#
# -------------------------------------------------
# -------------------------------------------------
#
# Epoca 11, Loss: 0.076, Accuracy: 97.002, Recall: 97.002, Precision: 97.002
# Loss_test: 0.078, Accuracy_test: 96.921, Recall_test: 96.921, Precision_test: 96.921
#
# -------------------------------------------------
# WARNING:absl:Found untraced functions such as dense_layer_call_fn, dense_layer_call_and_return_conditional_losses, dense_1_layer_call_fn, dense_1_layer_call_and_return_conditional_losses, dense_2_layer_call_fn while saving (showing 5 of 285). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Kika/Modelos guardados/Modelos/UNET-CBAM/UNET-CBAM.h5py/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Kika/Modelos guardados/Modelos/UNET-CBAM/UNET-CBAM.h5py/assets
# -------------------------------------------------
#
# Epoca 12, Loss: 0.076, Accuracy: 97.015, Recall: 97.015, Precision: 97.015
# Loss_test: 0.076, Accuracy_test: 97.036, Recall_test: 97.036, Precision_test: 97.036
#
# -------------------------------------------------
# -------------------------------------------------
#
# Epoca 13, Loss: 0.075, Accuracy: 97.031, Recall: 97.031, Precision: 97.031
# Loss_test: 0.077, Accuracy_test: 96.998, Recall_test: 96.998, Precision_test: 96.998
#
# -------------------------------------------------
# WARNING:absl:Found untraced functions such as dense_layer_call_fn, dense_layer_call_and_return_conditional_losses, dense_1_layer_call_fn, dense_1_layer_call_and_return_conditional_losses, dense_2_layer_call_fn while saving (showing 5 of 285). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Kika/Modelos guardados/Modelos/UNET-CBAM/UNET-CBAM.h5py/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Kika/Modelos guardados/Modelos/UNET-CBAM/UNET-CBAM.h5py/assets
# -------------------------------------------------
#
# Epoca 14, Loss: 0.075, Accuracy: 97.047, Recall: 97.046, Precision: 97.046
# Loss_test: 0.075, Accuracy_test: 97.074, Recall_test: 97.074, Precision_test: 97.074
#
# -------------------------------------------------
