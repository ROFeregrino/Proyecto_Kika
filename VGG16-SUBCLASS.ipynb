# %%
from tensorflow.keras.layers import BatchNormalization, MaxPooling2D, Flatten, UpSampling2D
from tensorflow.keras.layers import Layer, Dense, Input, Dropout, Conv2D, concatenate
from tensorflow.python.keras.layers.convolutional import Conv2DTranspose
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras import Model
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from google.colab import drive
from PIL import ImageOps
import tensorflow as tf
import numpy as np
import warnings
import datetime
import cv2 as cv
import PIL
import os



drive.mount('/content/drive')
warnings.filterwarnings("ignore")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Entrenamiento del modelo

# %% [markdown]
# ### Encoder

# %%
class bloque_1(Layer):
  def __init__(self, num_kernels, kernel_tam, ker_reg= None):
    super(bloque_1, self).__init__()
    self.conv1= Conv2D(num_kernels, kernel_size= kernel_tam,
                      padding= "same", kernel_regularizer= ker_reg,
                      activation= "relu")
    self.conv2= Conv2D(num_kernels, kernel_size= kernel_tam,
                      padding= "same", kernel_regularizer= ker_reg,
                      activation= "relu")
    
    self.bn1= BatchNormalization()
    self.bn2= BatchNormalization()
    
    self.mp= MaxPooling2D(3, strides = 2, padding= "same")

  def call(self, entrada_tensor):
    x= self.conv1(entrada_tensor)
    x= self.bn1(x)
    x= self.conv2(x)
    x= self.bn2(x)

    return x, self.mp(x)


class bloque_2(Layer):
  def __init__(self, num_kernels, kernel_tam, ker_reg= None):
    super(bloque_2, self).__init__()
    self.conv1= Conv2D(num_kernels, kernel_size= kernel_tam,
                      padding= "same", kernel_regularizer= ker_reg,
                      activation= "relu")
    self.conv2= Conv2D(num_kernels, kernel_size= kernel_tam,
                      padding= "same", kernel_regularizer= ker_reg,
                      activation= "relu")
    self.conv3= Conv2D(num_kernels, kernel_size= kernel_tam,
                      padding= "same", kernel_regularizer= ker_reg,
                      activation= "relu")
    
    self.bn1= BatchNormalization()
    self.bn2= BatchNormalization()
    self.bn3= BatchNormalization()
    
    self.mp= MaxPooling2D(3, strides = 2, padding= "same")

  def call(self, entrada_tensor):
    x= self.conv1(entrada_tensor)
    x= self.bn1(x)
    x= self.conv2(x)
    x= self.bn2(x)
    x= self.conv3(x)
    x= self.bn3(x)

    return x, self.mp(x)

# %% [markdown]
# ### Decoder

# %%
class up_conc(Layer):
  def __init__(self):
    super(up_conc, self).__init__()
    self.up_sampling= UpSampling2D(2)

  def call(self, entrada, res):
    x= self.up_sampling(entrada)
    return concatenate([x, res])

class conv_f(Layer):
  def __init__(self, num_kernels, kernel_tam, ker_reg= None):
    super(conv_f, self).__init__()
    self.conv1= Conv2D(num_kernels, kernel_size= kernel_tam,
                      padding= "same", kernel_regularizer= ker_reg,
                      activation= "relu")
    self.conv2= Conv2D(num_kernels, kernel_size= kernel_tam,
                      padding= "same", kernel_regularizer= ker_reg,
                      activation= "relu")
    self.conv3= Conv2D(num_kernels, kernel_size= kernel_tam,
                      padding= "same", kernel_regularizer= ker_reg,
                      activation= "relu")
    
    self.bn1= BatchNormalization()
    self.bn2= BatchNormalization()
    self.bn3= BatchNormalization()

    self.trans= Conv2DTranspose(int(num_kernels/2),
                                kernel_size= kernel_tam, 
                                padding= 'same', activation= 'relu')

  def call(self, entrada):
    x= self.conv1(entrada)
    x= self.bn1(x)
    x= self.conv2(x)
    x= self.bn2(x)
    x= self.conv3(x)
    x= self.bn3(x)

    return self.trans(x)


class conv_v(Layer):
  def __init__(self, num_kernels, kernel_tam, ker_reg= None):
    super(conv_v, self).__init__()
    self.conv1= Conv2D(num_kernels, kernel_size= kernel_tam,
                      padding= "same", kernel_regularizer= ker_reg,
                      activation= "relu")
    self.conv2= Conv2D(num_kernels, kernel_size= kernel_tam,
                      padding= "same", kernel_regularizer= ker_reg,
                      activation= "relu")
    self.bn1= BatchNormalization()
    self.bn2= BatchNormalization()

    self.trans= Conv2DTranspose(int(num_kernels/2),
                                kernel_size= kernel_tam, 
                                padding= 'same', activation= 'relu')

  def call(self, entrada):
    x= self.conv1(entrada)
    x= self.bn1(x)
    x= self.conv2(x)
    x= self.bn2(x)

    return self.trans(x)


class salida_dec(Layer):
  def __init__(self, num_kernels, kernel_tam, salida, ker_reg= None):
    super(salida_dec, self).__init__()
    self.conv1= Conv2D(num_kernels, kernel_size= kernel_tam,
                      padding= "same", kernel_regularizer= ker_reg,
                      activation= "relu")
    self.conv2= Conv2D(num_kernels, kernel_size= kernel_tam,
                      padding= "same", kernel_regularizer= ker_reg,
                      activation= "relu")
    
    self.bn1= BatchNormalization()
    self.bn2= BatchNormalization()
    self.convs= Conv2D(salida, kernel_tam, padding= "same", activation= "softmax")

  def call(self, entrada):
    x= self.conv1(entrada)
    x= self.bn1(x)
    x= self.conv2(x)
    x= self.bn2(x)
    
    return self.convs(x)

# %% [markdown]
# ### Modelo

# %%
class VGG_16(Model):
  def __init__(self, num_classes):
    super(VGG_16, self).__init__()

    # Parte del encoder
    self.eblock_1= bloque_1(64, 3)
    self.eblock_2= bloque_1(128, 3)
    self.eblock_3= bloque_1(256, 3)
    self.eblock_4= bloque_2(512, 3)
    self.eblock_5= bloque_2(512, 3)

    # Parte del decoder
    self.up_conc1= up_conc()
    self.up_conc2= up_conc()
    self.up_conc3= up_conc()
    self.up_conc4= up_conc()

    self.dblock_1= conv_f(1024, 3)
    self.dblock_2= conv_f(1024, 3)
    self.dblock_3= conv_v(512, 3)
    self.dblock_4= conv_v(256, 3)
    self.dblock_5= conv_v(128, 3)
    self.upsampl= UpSampling2D(2)
    self.dsalida= salida_dec(64, 3, num_classes)


  def call(self, entrada_tam):

    #Encoder: 64, 128, 256, 2X512
    _, x= self.eblock_1(entrada_tam)
    res1, x= self.eblock_2(x)
    res2, x= self.eblock_3(x)
    res3, x= self.eblock_4(x)
    res4, x= self.eblock_5(x)


    #Decoder: 2x1024, 512, 256, 128
    x= self.dblock_1(x)
    x= self.up_conc1(x, res4)
    x= self.dblock_2(x)
    x= self.up_conc2(x, res3)
    x= self.dblock_3(x)
    x= self.up_conc3(x, res2)
    x= self.dblock_4(x)
    x= self.up_conc4(x, res1)
    x= self.dblock_5(x)
    x= self.upsampl(x)

    # Salida: 64 y dos nodos para la segmentacion
    return self.dsalida(x)

  def build_graph(self, raw_shape):
    x= Input(shape= raw_shape)
    return Model(inputs= [x], outputs= self.call(x))

# %%
raw_input = (160, 160, 1)

mi_modelo= VGG_16(2)
y= mi_modelo(tf.ones(shape=(0, *raw_input)))

mi_modelo.build_graph(raw_input).summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 160, 160, 1  0           []
#                                 )]
#
#  bloque_1 (bloque_1)            ((None, 160, 160, 6  38080       ['input_1[0][0]']
#                                 4),
#                                  (None, 80, 80, 64)
#                                 )
#
#  bloque_1_1 (bloque_1)          ((None, 80, 80, 128  222464      ['bloque_1[0][1]']
#                                 ),
#                                  (None, 40, 40, 128
#                                 ))
#
#  bloque_1_2 (bloque_1)          ((None, 40, 40, 256  887296      ['bloque_1_1[0][1]']
#                                 ),
#                                  (None, 20, 20, 256
#                                 ))
#
#  bloque_2 (bloque_2)            ((None, 20, 20, 512  5905920     ['bloque_1_2[0][1]']
#                                 ),
#                                  (None, 10, 10, 512
#                                 ))
#
#  bloque_2_1 (bloque_2)          ((None, 10, 10, 512  7085568     ['bloque_2[0][1]']
#                                 ),
#                                  (None, 5, 5, 512))
#
#  conv_f (conv_f)                (None, 5, 5, 512)    28327424    ['bloque_2_1[0][1]']
#
#  up_conc (up_conc)              (None, 10, 10, 1024  0           ['conv_f[0][0]',
#                                 )                                 'bloque_2_1[0][0]']
#
#  conv_f_1 (conv_f)              (None, 10, 10, 512)  33046016    ['up_conc[0][0]']
#
#  up_conc_1 (up_conc)            (None, 20, 20, 1024  0           ['conv_f_1[0][0]',
#                                 )                                 'bloque_2[0][0]']
#
#  conv_v (conv_v)                (None, 20, 20, 256)  8262912     ['up_conc_1[0][0]']
#
#  up_conc_2 (up_conc)            (None, 40, 40, 512)  0           ['conv_v[0][0]',
#                                                                   'bloque_1_2[0][0]']
#
#  conv_v_1 (conv_v)              (None, 40, 40, 128)  2067072     ['up_conc_2[0][0]']
#
#  up_conc_3 (up_conc)            (None, 80, 80, 256)  0           ['conv_v_1[0][0]',
#                                                                   'bloque_1_1[0][0]']
#
#  conv_v_2 (conv_v)              (None, 80, 80, 64)   517440      ['up_conc_3[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 160, 160, 64  0          ['conv_v_2[0][0]']
#                                 )
#
#  salida_dec (salida_dec)        (None, 160, 160, 2)  75522       ['up_sampling2d_4[0][0]']
#
# ==================================================================================================
# Total params: 86,435,714
# Trainable params: 86,411,650
# Non-trainable params: 24,064
# __________________________________________________________________________________________________

# %% [markdown]
# ### Acodomo de los datos

# %%
# !unzip "/content/drive/MyDrive/Proyectos/Kika/Base de datos/Ent.zip" -d "/content/sample_data/"
# !unzip "/content/drive/MyDrive/Proyectos/Kika/Base de datos/Val.zip" -d "/content/sample_data/"
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#   inflating: /content/sample_data/Val/msk/4864.png
#   inflating: /content/sample_data/Val/msk/4865.png
#   inflating: /content/sample_data/Val/msk/4866.png
#   inflating: /content/sample_data/Val/msk/4867.png
#   inflating: /content/sample_data/Val/msk/4868.png
#   inflating: /content/sample_data/Val/msk/4869.png
#   inflating: /content/sample_data/Val/msk/487.png
#   inflating: /content/sample_data/Val/msk/4870.png
#   inflating: /content/sample_data/Val/msk/4871.png
#   inflating: /content/sample_data/Val/msk/4872.png
#   inflating: /content/sample_data/Val/msk/4873.png
#   inflating: /content/sample_data/Val/msk/4874.png
#   inflating: /content/sample_data/Val/msk/4875.png
#   inflating: /content/sample_data/Val/msk/488.png
#   inflating: /content/sample_data/Val/msk/4881.png
#   inflating: /content/sample_data/Val/msk/4882.png
#   inflating: /content/sample_data/Val/msk/4883.png
#   inflating: /content/sample_data/Val/msk/4884.png
#   inflating: /content/sample_data/Val/msk/4885.png
#   inflating: /content/sample_data/Val/msk/4886.png
#   inflating: /content/sample_data/Val/msk/4887.png
#   inflating: /content/sample_data/Val/msk/4888.png
#   inflating: /content/sample_data/Val/msk/4889.png
#   inflating: /content/sample_data/Val/msk/489.png
#   inflating: /content/sample_data/Val/msk/4890.png
#   inflating: /content/sample_data/Val/msk/4891.png
#   inflating: /content/sample_data/Val/msk/4892.png
#   inflating: /content/sample_data/Val/msk/4893.png
#   inflating: /content/sample_data/Val/msk/4894.png
#   inflating: /content/sample_data/Val/msk/4895.png
#   inflating: /content/sample_data/Val/msk/4896.png
#   inflating: /content/sample_data/Val/msk/4897.png
#   inflating: /content/sample_data/Val/msk/4898.png
#   inflating: /content/sample_data/Val/msk/4899.png
#   inflating: /content/sample_data/Val/msk/49.png
#   inflating: /content/sample_data/Val/msk/490.png
#   inflating: /content/sample_data/Val/msk/4900.png
#   inflating: /content/sample_data/Val/msk/4901.png
#   inflating: /content/sample_data/Val/msk/4902.png
#   inflating: /content/sample_data/Val/msk/4903.png
#   inflating: /content/sample_data/Val/msk/4904.png
#   inflating: /content/sample_data/Val/msk/4905.png
#   inflating: /content/sample_data/Val/msk/4906.png
#   inflating: /content/sample_data/Val/msk/4907.png
#   inflating: /content/sample_data/Val/msk/4908.png
#   inflating: /content/sample_data/Val/msk/4909.png
#   inflating: /content/sample_data/Val/msk/491.png
#   inflating: /content/sample_data/Val/msk/4910.png
#   inflating: /content/sample_data/Val/msk/4911.png
#   inflating: /content/sample_data/Val/msk/4912.png
#   inflating: /content/sample_data/Val/msk/4913.png
#   inflating: /content/sample_data/Val/msk/4914.png
#   inflating: /content/sample_data/Val/msk/4915.png
#   inflating: /content/sample_data/Val/msk/4916.png
#   inflating: /content/sample_data/Val/msk/4917.png
#   inflating: /content/sample_data/Val/msk/4918.png
#   inflating: /content/sample_data/Val/msk/4919.png
#   inflating: /content/sample_data/Val/msk/492.png
#   inflating: /content/sample_data/Val/msk/4920.png
#   inflating: /content/sample_data/Val/msk/4921.png
#   inflating: /content/sample_data/Val/msk/4922.png
#   inflating: /content/sample_data/Val/msk/4923.png
#   inflating: /content/sample_data/Val/msk/4924.png
#   inflating: /content/sample_data/Val/msk/4925.png
#   inflating: /content/sample_data/Val/msk/4926.png
#   inflating: /content/sample_data/Val/msk/4927.png
#   inflating: /content/sample_data/Val/msk/4928.png
#   inflating: /content/sample_data/Val/msk/4929.png
#   inflating: /content/sample_data/Val/msk/493.png
#   inflating: /content/sample_data/Val/msk/4930.png
#   inflating: /content/sample_data/Val/msk/4931.png
#   inflating: /content/sample_data/Val/msk/4932.png
#   inflating: /content/sample_data/Val/msk/4933.png
#   inflating: /content/sample_data/Val/msk/4934.png
#   inflating: /content/sample_data/Val/msk/4935.png
#   inflating: /content/sample_data/Val/msk/4936.png
#   inflating: /content/sample_data/Val/msk/4937.png
#   inflating: /content/sample_data/Val/msk/4938.png
#   inflating: /content/sample_data/Val/msk/4939.png
#   inflating: /content/sample_data/Val/msk/494.png
#   inflating: /content/sample_data/Val/msk/4940.png
#   inflating: /content/sample_data/Val/msk/4941.png
#   inflating: /content/sample_data/Val/msk/4947.png
#   inflating: /content/sample_data/Val/msk/495.png
#   inflating: /content/sample_data/Val/msk/4953.png
#   inflating: /content/sample_data/Val/msk/4959.png
#   inflating: /content/sample_data/Val/msk/496.png
#   inflating: /content/sample_data/Val/msk/4960.png
#   inflating: /content/sample_data/Val/msk/4961.png
#   inflating: /content/sample_data/Val/msk/4962.png
#   inflating: /content/sample_data/Val/msk/4963.png
#   inflating: /content/sample_data/Val/msk/4964.png
#   inflating: /content/sample_data/Val/msk/4965.png
#   inflating: /content/sample_data/Val/msk/4966.png
#   inflating: /content/sample_data/Val/msk/4967.png
#   inflating: /content/sample_data/Val/msk/4968.png
#   inflating: /content/sample_data/Val/msk/4969.png
#   inflating: /content/sample_data/Val/msk/497.png
#   inflating: /content/sample_data/Val/msk/4970.png
#   inflating: /content/sample_data/Val/msk/4971.png
#   inflating: /content/sample_data/Val/msk/4972.png
#   inflating: /content/sample_data/Val/msk/4973.png
#   inflating: /content/sample_data/Val/msk/4974.png
#   inflating: /content/sample_data/Val/msk/4975.png
#   inflating: /content/sample_data/Val/msk/4976.png
#   inflating: /content/sample_data/Val/msk/4977.png
#   inflating: /content/sample_data/Val/msk/4978.png
#   inflating: /content/sample_data/Val/msk/4979.png
#   inflating: /content/sample_data/Val/msk/498.png
#   inflating: /content/sample_data/Val/msk/4980.png
#   inflating: /content/sample_data/Val/msk/4981.png
#   inflating: /content/sample_data/Val/msk/4982.png
#   inflating: /content/sample_data/Val/msk/4983.png
#   inflating: /content/sample_data/Val/msk/4984.png
#   inflating: /content/sample_data/Val/msk/4985.png
#   inflating: /content/sample_data/Val/msk/4986.png
#   inflating: /content/sample_data/Val/msk/4987.png
#   inflating: /content/sample_data/Val/msk/4988.png
#   inflating: /content/sample_data/Val/msk/4989.png
#   inflating: /content/sample_data/Val/msk/499.png
#   inflating: /content/sample_data/Val/msk/4990.png
#   inflating: /content/sample_data/Val/msk/4991.png
#   inflating: /content/sample_data/Val/msk/4992.png
#   inflating: /content/sample_data/Val/msk/4993.png
#   inflating: /content/sample_data/Val/msk/4994.png
#   inflating: /content/sample_data/Val/msk/4995.png
#   inflating: /content/sample_data/Val/msk/4996.png
#   inflating: /content/sample_data/Val/msk/4997.png
#   inflating: /content/sample_data/Val/msk/4998.png
#   inflating: /content/sample_data/Val/msk/4999.png
#   inflating: /content/sample_data/Val/msk/5.png
#   inflating: /content/sample_data/Val/msk/50.png
#   inflating: /content/sample_data/Val/msk/500.png
#   inflating: /content/sample_data/Val/msk/5000.png
#   inflating: /content/sample_data/Val/msk/5001.png
#   inflating: /content/sample_data/Val/msk/5002.png
#   inflating: /content/sample_data/Val/msk/5003.png
#   inflating: /content/sample_data/Val/msk/5004.png
#   inflating: /content/sample_data/Val/msk/5005.png
#   inflating: /content/sample_data/Val/msk/5006.png
#   inflating: /content/sample_data/Val/msk/5007.png
#   inflating: /content/sample_data/Val/msk/5008.png
#   inflating: /content/sample_data/Val/msk/5009.png
#   inflating: /content/sample_data/Val/msk/501.png
#   inflating: /content/sample_data/Val/msk/5010.png
#   inflating: /content/sample_data/Val/msk/5011.png
#   inflating: /content/sample_data/Val/msk/5012.png
#   inflating: /content/sample_data/Val/msk/5013.png
#   inflating: /content/sample_data/Val/msk/5014.png
#   inflating: /content/sample_data/Val/msk/5015.png
#   inflating: /content/sample_data/Val/msk/5016.png
#   inflating: /content/sample_data/Val/msk/5017.png
#   inflating: /content/sample_data/Val/msk/5018.png
#   inflating: /content/sample_data/Val/msk/5019.png
#   inflating: /content/sample_data/Val/msk/502.png
#   inflating: /content/sample_data/Val/msk/5020.png
#   inflating: /content/sample_data/Val/msk/5021.png
#   inflating: /content/sample_data/Val/msk/5022.png
#   inflating: /content/sample_data/Val/msk/5023.png
#   inflating: /content/sample_data/Val/msk/5024.png
#   inflating: /content/sample_data/Val/msk/5025.png
#   inflating: /content/sample_data/Val/msk/5026.png
#   inflating: /content/sample_data/Val/msk/5027.png
#   inflating: /content/sample_data/Val/msk/5028.png
#   inflating: /content/sample_data/Val/msk/5029.png
#   inflating: /content/sample_data/Val/msk/503.png
#   inflating: /content/sample_data/Val/msk/5030.png
#   inflating: /content/sample_data/Val/msk/5031.png
#   inflating: /content/sample_data/Val/msk/5037.png
#   inflating: /content/sample_data/Val/msk/504.png
#   inflating: /content/sample_data/Val/msk/5043.png
#   inflating: /content/sample_data/Val/msk/5049.png
#   inflating: /content/sample_data/Val/msk/505.png
#   inflating: /content/sample_data/Val/msk/5055.png
#   inflating: /content/sample_data/Val/msk/5056.png
#   inflating: /content/sample_data/Val/msk/5057.png
#   inflating: /content/sample_data/Val/msk/5058.png
#   inflating: /content/sample_data/Val/msk/5059.png
#   inflating: /content/sample_data/Val/msk/506.png
#   inflating: /content/sample_data/Val/msk/5060.png
#   inflating: /content/sample_data/Val/msk/5061.png
#   inflating: /content/sample_data/Val/msk/5062.png
#   inflating: /content/sample_data/Val/msk/5063.png
#   inflating: /content/sample_data/Val/msk/5064.png
#   inflating: /content/sample_data/Val/msk/5065.png
#   inflating: /content/sample_data/Val/msk/5066.png
#   inflating: /content/sample_data/Val/msk/5067.png
#   inflating: /content/sample_data/Val/msk/5068.png
#   inflating: /content/sample_data/Val/msk/5069.png
#   inflating: /content/sample_data/Val/msk/507.png
#   inflating: /content/sample_data/Val/msk/5070.png
#   inflating: /content/sample_data/Val/msk/5071.png
#   inflating: /content/sample_data/Val/msk/5072.png
#   inflating: /content/sample_data/Val/msk/5073.png
#   inflating: /content/sample_data/Val/msk/5074.png
#   inflating: /content/sample_data/Val/msk/5075.png
#   inflating: /content/sample_data/Val/msk/5076.png
#   inflating: /content/sample_data/Val/msk/5077.png
#   inflating: /content/sample_data/Val/msk/5078.png
#   inflating: /content/sample_data/Val/msk/5079.png
#   inflating: /content/sample_data/Val/msk/508.png
#   inflating: /content/sample_data/Val/msk/5080.png
#   inflating: /content/sample_data/Val/msk/5081.png
#   inflating: /content/sample_data/Val/msk/5082.png
#   inflating: /content/sample_data/Val/msk/5083.png
#   inflating: /content/sample_data/Val/msk/5084.png
#   inflating: /content/sample_data/Val/msk/5085.png
#   inflating: /content/sample_data/Val/msk/5086.png
#   inflating: /content/sample_data/Val/msk/5087.png
#   inflating: /content/sample_data/Val/msk/5088.png
#   inflating: /content/sample_data/Val/msk/5089.png
#   inflating: /content/sample_data/Val/msk/509.png
#   inflating: /content/sample_data/Val/msk/5090.png
#   inflating: /content/sample_data/Val/msk/5091.png
#   inflating: /content/sample_data/Val/msk/5092.png
#   inflating: /content/sample_data/Val/msk/5093.png
#   inflating: /content/sample_data/Val/msk/5094.png
#   inflating: /content/sample_data/Val/msk/5095.png
#   inflating: /content/sample_data/Val/msk/5096.png
#   inflating: /content/sample_data/Val/msk/5097.png
#   inflating: /content/sample_data/Val/msk/5098.png
#   inflating: /content/sample_data/Val/msk/5099.png
#   inflating: /content/sample_data/Val/msk/51.png
#   inflating: /content/sample_data/Val/msk/510.png
#   inflating: /content/sample_data/Val/msk/5100.png
#   inflating: /content/sample_data/Val/msk/5101.png
#   inflating: /content/sample_data/Val/msk/5102.png
#   inflating: /content/sample_data/Val/msk/5103.png
#   inflating: /content/sample_data/Val/msk/5104.png
#   inflating: /content/sample_data/Val/msk/5105.png
#   inflating: /content/sample_data/Val/msk/5106.png
#   inflating: /content/sample_data/Val/msk/5107.png
#   inflating: /content/sample_data/Val/msk/5108.png
#   inflating: /content/sample_data/Val/msk/5109.png
#   inflating: /content/sample_data/Val/msk/5110.png
#   inflating: /content/sample_data/Val/msk/5111.png
#   inflating: /content/sample_data/Val/msk/5112.png
#   inflating: /content/sample_data/Val/msk/5113.png
#   inflating: /content/sample_data/Val/msk/5114.png
#   inflating: /content/sample_data/Val/msk/5115.png
#   inflating: /content/sample_data/Val/msk/5116.png
#   inflating: /content/sample_data/Val/msk/5117.png
#   inflating: /content/sample_data/Val/msk/5118.png
#   inflating: /content/sample_data/Val/msk/5119.png
#   inflating: /content/sample_data/Val/msk/5120.png
#   inflating: /content/sample_data/Val/msk/5121.png
#   inflating: /content/sample_data/Val/msk/5127.png
#   inflating: /content/sample_data/Val/msk/5133.png
#   inflating: /content/sample_data/Val/msk/5139.png
#   inflating: /content/sample_data/Val/msk/5145.png
#   inflating: /content/sample_data/Val/msk/5146.png
#   inflating: /content/sample_data/Val/msk/5147.png
#   inflating: /content/sample_data/Val/msk/5148.png
#   inflating: /content/sample_data/Val/msk/5149.png
#   inflating: /content/sample_data/Val/msk/5150.png
#   inflating: /content/sample_data/Val/msk/5151.png
#   inflating: /content/sample_data/Val/msk/5157.png
#   inflating: /content/sample_data/Val/msk/5158.png
#   inflating: /content/sample_data/Val/msk/5159.png
#   inflating: /content/sample_data/Val/msk/516.png
#   inflating: /content/sample_data/Val/msk/5160.png
#   inflating: /content/sample_data/Val/msk/5161.png
#   inflating: /content/sample_data/Val/msk/5162.png
#   inflating: /content/sample_data/Val/msk/5163.png
#   inflating: /content/sample_data/Val/msk/5164.png
#   inflating: /content/sample_data/Val/msk/5165.png
#   inflating: /content/sample_data/Val/msk/5166.png
#   inflating: /content/sample_data/Val/msk/5167.png
#   inflating: /content/sample_data/Val/msk/5168.png
#   inflating: /content/sample_data/Val/msk/5169.png
#   inflating: /content/sample_data/Val/msk/517.png
#   inflating: /content/sample_data/Val/msk/5170.png
#   inflating: /content/sample_data/Val/msk/5171.png
#   inflating: /content/sample_data/Val/msk/5172.png
#   inflating: /content/sample_data/Val/msk/5173.png
#   inflating: /content/sample_data/Val/msk/5174.png
#   inflating: /content/sample_data/Val/msk/5175.png
#   inflating: /content/sample_data/Val/msk/5176.png
#   inflating: /content/sample_data/Val/msk/5177.png
#   inflating: /content/sample_data/Val/msk/5178.png
#   inflating: /content/sample_data/Val/msk/5179.png
#   inflating: /content/sample_data/Val/msk/518.png
#   inflating: /content/sample_data/Val/msk/5180.png
#   inflating: /content/sample_data/Val/msk/5181.png
#   inflating: /content/sample_data/Val/msk/5182.png
#   inflating: /content/sample_data/Val/msk/5183.png
#   inflating: /content/sample_data/Val/msk/5184.png
#   inflating: /content/sample_data/Val/msk/5185.png
#   inflating: /content/sample_data/Val/msk/5186.png
#   inflating: /content/sample_data/Val/msk/5187.png
#   inflating: /content/sample_data/Val/msk/5188.png
#   inflating: /content/sample_data/Val/msk/5189.png
#   inflating: /content/sample_data/Val/msk/519.png
#   inflating: /content/sample_data/Val/msk/5190.png
#   inflating: /content/sample_data/Val/msk/5191.png
#   inflating: /content/sample_data/Val/msk/5192.png
#   inflating: /content/sample_data/Val/msk/5193.png
#   inflating: /content/sample_data/Val/msk/5199.png
#   inflating: /content/sample_data/Val/msk/52.png
#   inflating: /content/sample_data/Val/msk/520.png
#   inflating: /content/sample_data/Val/msk/5200.png
#   inflating: /content/sample_data/Val/msk/5201.png
#   inflating: /content/sample_data/Val/msk/5202.png
#   inflating: /content/sample_data/Val/msk/5203.png
#   inflating: /content/sample_data/Val/msk/5204.png
#   inflating: /content/sample_data/Val/msk/5205.png
#   inflating: /content/sample_data/Val/msk/521.png
#   inflating: /content/sample_data/Val/msk/5211.png
#   inflating: /content/sample_data/Val/msk/5217.png
#   inflating: /content/sample_data/Val/msk/522.png
#   inflating: /content/sample_data/Val/msk/5223.png
#   inflating: /content/sample_data/Val/msk/5229.png
#   inflating: /content/sample_data/Val/msk/523.png
#   inflating: /content/sample_data/Val/msk/5235.png
#   inflating: /content/sample_data/Val/msk/524.png
#   inflating: /content/sample_data/Val/msk/5241.png
#   inflating: /content/sample_data/Val/msk/5247.png
#   inflating: /content/sample_data/Val/msk/5248.png
#   inflating: /content/sample_data/Val/msk/5249.png
#   inflating: /content/sample_data/Val/msk/525.png
#   inflating: /content/sample_data/Val/msk/5250.png
#   inflating: /content/sample_data/Val/msk/5251.png
#   inflating: /content/sample_data/Val/msk/5252.png
#   inflating: /content/sample_data/Val/msk/5253.png
#   inflating: /content/sample_data/Val/msk/5254.png
#   inflating: /content/sample_data/Val/msk/5255.png
#   inflating: /content/sample_data/Val/msk/5256.png
#   inflating: /content/sample_data/Val/msk/5257.png
#   inflating: /content/sample_data/Val/msk/5258.png
#   inflating: /content/sample_data/Val/msk/5259.png
#   inflating: /content/sample_data/Val/msk/526.png
#   inflating: /content/sample_data/Val/msk/5265.png
#   inflating: /content/sample_data/Val/msk/5266.png
#   inflating: /content/sample_data/Val/msk/5267.png
#   inflating: /content/sample_data/Val/msk/5268.png
#   inflating: /content/sample_data/Val/msk/5269.png
#   inflating: /content/sample_data/Val/msk/527.png
#   inflating: /content/sample_data/Val/msk/5270.png
#   inflating: /content/sample_data/Val/msk/5271.png
#   inflating: /content/sample_data/Val/msk/5272.png
#   inflating: /content/sample_data/Val/msk/5273.png
#   inflating: /content/sample_data/Val/msk/5274.png
#   inflating: /content/sample_data/Val/msk/5275.png
#   inflating: /content/sample_data/Val/msk/5276.png
#   inflating: /content/sample_data/Val/msk/5277.png
#   inflating: /content/sample_data/Val/msk/528.png
#   inflating: /content/sample_data/Val/msk/5283.png
#   inflating: /content/sample_data/Val/msk/5289.png
#   inflating: /content/sample_data/Val/msk/529.png
#   inflating: /content/sample_data/Val/msk/5295.png
#   inflating: /content/sample_data/Val/msk/53.png
#   inflating: /content/sample_data/Val/msk/530.png
#   inflating: /content/sample_data/Val/msk/5301.png
#   inflating: /content/sample_data/Val/msk/5307.png
#   inflating: /content/sample_data/Val/msk/5308.png
#   inflating: /content/sample_data/Val/msk/5309.png
#   inflating: /content/sample_data/Val/msk/531.png
#   inflating: /content/sample_data/Val/msk/5310.png
#   inflating: /content/sample_data/Val/msk/5311.png
#   inflating: /content/sample_data/Val/msk/5312.png
#   inflating: /content/sample_data/Val/msk/5313.png
#   inflating: /content/sample_data/Val/msk/5314.png
#   inflating: /content/sample_data/Val/msk/5315.png
#   inflating: /content/sample_data/Val/msk/5316.png
#   inflating: /content/sample_data/Val/msk/5317.png
#   inflating: /content/sample_data/Val/msk/5318.png
#   inflating: /content/sample_data/Val/msk/5319.png
#   inflating: /content/sample_data/Val/msk/532.png
#   inflating: /content/sample_data/Val/msk/5325.png
#   inflating: /content/sample_data/Val/msk/5326.png
#   inflating: /content/sample_data/Val/msk/5327.png
#   inflating: /content/sample_data/Val/msk/5328.png
#   inflating: /content/sample_data/Val/msk/5329.png
#   inflating: /content/sample_data/Val/msk/533.png
#   inflating: /content/sample_data/Val/msk/5330.png
#   inflating: /content/sample_data/Val/msk/5331.png
#   inflating: /content/sample_data/Val/msk/5332.png
#   inflating: /content/sample_data/Val/msk/5333.png
#   inflating: /content/sample_data/Val/msk/5334.png
#   inflating: /content/sample_data/Val/msk/5335.png
#   inflating: /content/sample_data/Val/msk/5336.png
#   inflating: /content/sample_data/Val/msk/5337.png
#   inflating: /content/sample_data/Val/msk/5338.png
#   inflating: /content/sample_data/Val/msk/5339.png
#   inflating: /content/sample_data/Val/msk/534.png
#   inflating: /content/sample_data/Val/msk/5340.png
#   inflating: /content/sample_data/Val/msk/5341.png
#   inflating: /content/sample_data/Val/msk/5342.png
#   inflating: /content/sample_data/Val/msk/5343.png
#   inflating: /content/sample_data/Val/msk/5344.png
#   inflating: /content/sample_data/Val/msk/5345.png
#   inflating: /content/sample_data/Val/msk/5346.png
#   inflating: /content/sample_data/Val/msk/5347.png
#   inflating: /content/sample_data/Val/msk/5348.png
#   inflating: /content/sample_data/Val/msk/5349.png
#   inflating: /content/sample_data/Val/msk/535.png
#   inflating: /content/sample_data/Val/msk/5350.png
#   inflating: /content/sample_data/Val/msk/5351.png
#   inflating: /content/sample_data/Val/msk/5352.png
#   inflating: /content/sample_data/Val/msk/5353.png
#   inflating: /content/sample_data/Val/msk/5354.png
#   inflating: /content/sample_data/Val/msk/5355.png
#   inflating: /content/sample_data/Val/msk/5356.png
#   inflating: /content/sample_data/Val/msk/5357.png
#   inflating: /content/sample_data/Val/msk/5358.png
#   inflating: /content/sample_data/Val/msk/5359.png
#   inflating: /content/sample_data/Val/msk/536.png
#   inflating: /content/sample_data/Val/msk/5360.png
#   inflating: /content/sample_data/Val/msk/5361.png
#   inflating: /content/sample_data/Val/msk/5362.png
#   inflating: /content/sample_data/Val/msk/5363.png
#   inflating: /content/sample_data/Val/msk/5364.png
#   inflating: /content/sample_data/Val/msk/5365.png
#   inflating: /content/sample_data/Val/msk/5366.png
#   inflating: /content/sample_data/Val/msk/5367.png
#   inflating: /content/sample_data/Val/msk/5368.png
#   inflating: /content/sample_data/Val/msk/5369.png
#   inflating: /content/sample_data/Val/msk/537.png
#   inflating: /content/sample_data/Val/msk/5370.png
#   inflating: /content/sample_data/Val/msk/5371.png
#   inflating: /content/sample_data/Val/msk/5372.png
#   inflating: /content/sample_data/Val/msk/5373.png
#   inflating: /content/sample_data/Val/msk/5379.png
#   inflating: /content/sample_data/Val/msk/538.png
#   inflating: /content/sample_data/Val/msk/5385.png
#   inflating: /content/sample_data/Val/msk/5386.png
#   inflating: /content/sample_data/Val/msk/5387.png
#   inflating: /content/sample_data/Val/msk/5388.png
#   inflating: /content/sample_data/Val/msk/5389.png
#   inflating: /content/sample_data/Val/msk/539.png
#   inflating: /content/sample_data/Val/msk/5390.png
#   inflating: /content/sample_data/Val/msk/5391.png
#   inflating: /content/sample_data/Val/msk/5392.png
#   inflating: /content/sample_data/Val/msk/5393.png
#   inflating: /content/sample_data/Val/msk/5394.png
#   inflating: /content/sample_data/Val/msk/5395.png
#   inflating: /content/sample_data/Val/msk/5396.png
#   inflating: /content/sample_data/Val/msk/5397.png
#   inflating: /content/sample_data/Val/msk/5398.png
#   inflating: /content/sample_data/Val/msk/5399.png
#   inflating: /content/sample_data/Val/msk/54.png
#   inflating: /content/sample_data/Val/msk/540.png
#   inflating: /content/sample_data/Val/msk/5400.png
#   inflating: /content/sample_data/Val/msk/5401.png
#   inflating: /content/sample_data/Val/msk/5402.png
#   inflating: /content/sample_data/Val/msk/5403.png
#   inflating: /content/sample_data/Val/msk/5404.png
#   inflating: /content/sample_data/Val/msk/5405.png
#   inflating: /content/sample_data/Val/msk/5406.png
#   inflating: /content/sample_data/Val/msk/5407.png
#   inflating: /content/sample_data/Val/msk/5408.png
#   inflating: /content/sample_data/Val/msk/5409.png
#   inflating: /content/sample_data/Val/msk/5410.png
#   inflating: /content/sample_data/Val/msk/5411.png
#   inflating: /content/sample_data/Val/msk/5412.png
#   inflating: /content/sample_data/Val/msk/5413.png
#   inflating: /content/sample_data/Val/msk/5414.png
#   inflating: /content/sample_data/Val/msk/5415.png
#   inflating: /content/sample_data/Val/msk/5416.png
#   inflating: /content/sample_data/Val/msk/5417.png
#   inflating: /content/sample_data/Val/msk/5418.png
#   inflating: /content/sample_data/Val/msk/5419.png
#   inflating: /content/sample_data/Val/msk/5420.png
#   inflating: /content/sample_data/Val/msk/5421.png
#   inflating: /content/sample_data/Val/msk/5422.png
#   inflating: /content/sample_data/Val/msk/5423.png
#   inflating: /content/sample_data/Val/msk/5424.png
#   inflating: /content/sample_data/Val/msk/5425.png
#   inflating: /content/sample_data/Val/msk/5426.png
#   inflating: /content/sample_data/Val/msk/5427.png
#   inflating: /content/sample_data/Val/msk/5428.png
#   inflating: /content/sample_data/Val/msk/5429.png
#   inflating: /content/sample_data/Val/msk/5430.png
#   inflating: /content/sample_data/Val/msk/5431.png
#   inflating: /content/sample_data/Val/msk/5432.png
#   inflating: /content/sample_data/Val/msk/5433.png
#   inflating: /content/sample_data/Val/msk/5439.png
#   inflating: /content/sample_data/Val/msk/5440.png
#   inflating: /content/sample_data/Val/msk/5441.png
#   inflating: /content/sample_data/Val/msk/5442.png
#   inflating: /content/sample_data/Val/msk/5443.png
#   inflating: /content/sample_data/Val/msk/5444.png
#   inflating: /content/sample_data/Val/msk/5445.png
#   inflating: /content/sample_data/Val/msk/5446.png
#   inflating: /content/sample_data/Val/msk/5447.png
#   inflating: /content/sample_data/Val/msk/5448.png
#   inflating: /content/sample_data/Val/msk/5449.png
#   inflating: /content/sample_data/Val/msk/5450.png
#   inflating: /content/sample_data/Val/msk/5451.png
#   inflating: /content/sample_data/Val/msk/5457.png
#   inflating: /content/sample_data/Val/msk/5458.png
#   inflating: /content/sample_data/Val/msk/5459.png
#   inflating: /content/sample_data/Val/msk/546.png
#   inflating: /content/sample_data/Val/msk/5460.png
#   inflating: /content/sample_data/Val/msk/5461.png
#   inflating: /content/sample_data/Val/msk/5462.png
#   inflating: /content/sample_data/Val/msk/5463.png
#   inflating: /content/sample_data/Val/msk/5464.png
#   inflating: /content/sample_data/Val/msk/5465.png
#   inflating: /content/sample_data/Val/msk/5466.png
#   inflating: /content/sample_data/Val/msk/5467.png
#   inflating: /content/sample_data/Val/msk/5468.png
#   inflating: /content/sample_data/Val/msk/5469.png
#   inflating: /content/sample_data/Val/msk/547.png
#   inflating: /content/sample_data/Val/msk/5470.png
#   inflating: /content/sample_data/Val/msk/5471.png
#   inflating: /content/sample_data/Val/msk/5472.png
#   inflating: /content/sample_data/Val/msk/5473.png
#   inflating: /content/sample_data/Val/msk/5474.png
#   inflating: /content/sample_data/Val/msk/5475.png
#   inflating: /content/sample_data/Val/msk/5476.png
#   inflating: /content/sample_data/Val/msk/5477.png
#   inflating: /content/sample_data/Val/msk/5478.png
#   inflating: /content/sample_data/Val/msk/5479.png
#   inflating: /content/sample_data/Val/msk/548.png
#   inflating: /content/sample_data/Val/msk/5480.png
#   inflating: /content/sample_data/Val/msk/5481.png
#   inflating: /content/sample_data/Val/msk/5482.png
#   inflating: /content/sample_data/Val/msk/5483.png
#   inflating: /content/sample_data/Val/msk/5484.png
#   inflating: /content/sample_data/Val/msk/5485.png
#   inflating: /content/sample_data/Val/msk/5486.png
#   inflating: /content/sample_data/Val/msk/5487.png
#   inflating: /content/sample_data/Val/msk/5488.png
#   inflating: /content/sample_data/Val/msk/5489.png
#   inflating: /content/sample_data/Val/msk/549.png
#   inflating: /content/sample_data/Val/msk/5490.png
#   inflating: /content/sample_data/Val/msk/5491.png
#   inflating: /content/sample_data/Val/msk/5492.png
#   inflating: /content/sample_data/Val/msk/5493.png
#   inflating: /content/sample_data/Val/msk/5494.png
#   inflating: /content/sample_data/Val/msk/5495.png
#   inflating: /content/sample_data/Val/msk/5496.png
#   inflating: /content/sample_data/Val/msk/5497.png
#   inflating: /content/sample_data/Val/msk/5498.png
#   inflating: /content/sample_data/Val/msk/5499.png
#   inflating: /content/sample_data/Val/msk/55.png
#   inflating: /content/sample_data/Val/msk/550.png
#   inflating: /content/sample_data/Val/msk/5500.png
#   inflating: /content/sample_data/Val/msk/5501.png
#   inflating: /content/sample_data/Val/msk/5502.png
#   inflating: /content/sample_data/Val/msk/5503.png
#   inflating: /content/sample_data/Val/msk/5504.png
#   inflating: /content/sample_data/Val/msk/5505.png
#   inflating: /content/sample_data/Val/msk/5506.png
#   inflating: /content/sample_data/Val/msk/5507.png
#   inflating: /content/sample_data/Val/msk/5508.png
#   inflating: /content/sample_data/Val/msk/5509.png
#   inflating: /content/sample_data/Val/msk/551.png
#   inflating: /content/sample_data/Val/msk/5510.png
#   inflating: /content/sample_data/Val/msk/5511.png
#   inflating: /content/sample_data/Val/msk/5512.png
#   inflating: /content/sample_data/Val/msk/5513.png
#   inflating: /content/sample_data/Val/msk/5514.png
#   inflating: /content/sample_data/Val/msk/5515.png
#   inflating: /content/sample_data/Val/msk/5516.png
#   inflating: /content/sample_data/Val/msk/5517.png
#   inflating: /content/sample_data/Val/msk/5518.png
#   inflating: /content/sample_data/Val/msk/5519.png
#   inflating: /content/sample_data/Val/msk/552.png
#   inflating: /content/sample_data/Val/msk/5520.png
#   inflating: /content/sample_data/Val/msk/5521.png
#   inflating: /content/sample_data/Val/msk/5522.png
#   inflating: /content/sample_data/Val/msk/5523.png
#   inflating: /content/sample_data/Val/msk/5524.png
#   inflating: /content/sample_data/Val/msk/5525.png
#   inflating: /content/sample_data/Val/msk/5526.png
#   inflating: /content/sample_data/Val/msk/5527.png
#   inflating: /content/sample_data/Val/msk/5528.png
#   inflating: /content/sample_data/Val/msk/5529.png
#   inflating: /content/sample_data/Val/msk/553.png
#   inflating: /content/sample_data/Val/msk/5530.png
#   inflating: /content/sample_data/Val/msk/5531.png
#   inflating: /content/sample_data/Val/msk/5532.png
#   inflating: /content/sample_data/Val/msk/5533.png
#   inflating: /content/sample_data/Val/msk/5534.png
#   inflating: /content/sample_data/Val/msk/5535.png
#   inflating: /content/sample_data/Val/msk/5536.png
#   inflating: /content/sample_data/Val/msk/5537.png
#   inflating: /content/sample_data/Val/msk/5538.png
#   inflating: /content/sample_data/Val/msk/5539.png
#   inflating: /content/sample_data/Val/msk/554.png
#   inflating: /content/sample_data/Val/msk/5540.png
#   inflating: /content/sample_data/Val/msk/5541.png
#   inflating: /content/sample_data/Val/msk/5542.png
#   inflating: /content/sample_data/Val/msk/5543.png
#   inflating: /content/sample_data/Val/msk/5544.png
#   inflating: /content/sample_data/Val/msk/5545.png
#   inflating: /content/sample_data/Val/msk/5546.png
#   inflating: /content/sample_data/Val/msk/5547.png
#   inflating: /content/sample_data/Val/msk/5548.png
#   inflating: /content/sample_data/Val/msk/5549.png
#   inflating: /content/sample_data/Val/msk/555.png
#   inflating: /content/sample_data/Val/msk/5550.png
#   inflating: /content/sample_data/Val/msk/5551.png
#   inflating: /content/sample_data/Val/msk/5552.png
#   inflating: /content/sample_data/Val/msk/5553.png
#   inflating: /content/sample_data/Val/msk/5554.png
#   inflating: /content/sample_data/Val/msk/5555.png
#   inflating: /content/sample_data/Val/msk/5556.png
#   inflating: /content/sample_data/Val/msk/5557.png
#   inflating: /content/sample_data/Val/msk/5558.png
#   inflating: /content/sample_data/Val/msk/5559.png
#   inflating: /content/sample_data/Val/msk/556.png
#   inflating: /content/sample_data/Val/msk/5560.png
#   inflating: /content/sample_data/Val/msk/5561.png
#   inflating: /content/sample_data/Val/msk/5562.png
#   inflating: /content/sample_data/Val/msk/5563.png
#   inflating: /content/sample_data/Val/msk/5564.png
#   inflating: /content/sample_data/Val/msk/5565.png
#   inflating: /content/sample_data/Val/msk/5566.png
#   inflating: /content/sample_data/Val/msk/5567.png
#   inflating: /content/sample_data/Val/msk/5568.png
#   inflating: /content/sample_data/Val/msk/5569.png
#   inflating: /content/sample_data/Val/msk/557.png
#   inflating: /content/sample_data/Val/msk/5570.png
#   inflating: /content/sample_data/Val/msk/5571.png
#   inflating: /content/sample_data/Val/msk/5572.png
#   inflating: /content/sample_data/Val/msk/5573.png
#   inflating: /content/sample_data/Val/msk/5574.png
#   inflating: /content/sample_data/Val/msk/5575.png
#   inflating: /content/sample_data/Val/msk/5576.png
#   inflating: /content/sample_data/Val/msk/5577.png
#   inflating: /content/sample_data/Val/msk/5578.png
#   inflating: /content/sample_data/Val/msk/5579.png
#   inflating: /content/sample_data/Val/msk/558.png
#   inflating: /content/sample_data/Val/msk/5580.png
#   inflating: /content/sample_data/Val/msk/5581.png
#   inflating: /content/sample_data/Val/msk/5582.png
#   inflating: /content/sample_data/Val/msk/5583.png
#   inflating: /content/sample_data/Val/msk/5584.png
#   inflating: /content/sample_data/Val/msk/5585.png
#   inflating: /content/sample_data/Val/msk/5586.png
#   inflating: /content/sample_data/Val/msk/5587.png
#   inflating: /content/sample_data/Val/msk/5588.png
#   inflating: /content/sample_data/Val/msk/5589.png
#   inflating: /content/sample_data/Val/msk/559.png
#   inflating: /content/sample_data/Val/msk/5590.png
#   inflating: /content/sample_data/Val/msk/5591.png
#   inflating: /content/sample_data/Val/msk/5592.png
#   inflating: /content/sample_data/Val/msk/5593.png
#   inflating: /content/sample_data/Val/msk/5594.png
#   inflating: /content/sample_data/Val/msk/5595.png
#   inflating: /content/sample_data/Val/msk/5596.png
#   inflating: /content/sample_data/Val/msk/5597.png
#   inflating: /content/sample_data/Val/msk/5598.png
#   inflating: /content/sample_data/Val/msk/5599.png
#   inflating: /content/sample_data/Val/msk/56.png
#   inflating: /content/sample_data/Val/msk/560.png
#   inflating: /content/sample_data/Val/msk/5600.png
#   inflating: /content/sample_data/Val/msk/5601.png
#   inflating: /content/sample_data/Val/msk/5602.png
#   inflating: /content/sample_data/Val/msk/5603.png
#   inflating: /content/sample_data/Val/msk/5604.png
#   inflating: /content/sample_data/Val/msk/5605.png
#   inflating: /content/sample_data/Val/msk/5606.png
#   inflating: /content/sample_data/Val/msk/5607.png
#   inflating: /content/sample_data/Val/msk/5608.png
#   inflating: /content/sample_data/Val/msk/5609.png
#   inflating: /content/sample_data/Val/msk/561.png
#   inflating: /content/sample_data/Val/msk/5610.png
#   inflating: /content/sample_data/Val/msk/5611.png
#   inflating: /content/sample_data/Val/msk/5612.png
#   inflating: /content/sample_data/Val/msk/5613.png
#   inflating: /content/sample_data/Val/msk/5614.png
#   inflating: /content/sample_data/Val/msk/5615.png
#   inflating: /content/sample_data/Val/msk/5616.png
#   inflating: /content/sample_data/Val/msk/5617.png
#   inflating: /content/sample_data/Val/msk/5618.png
#   inflating: /content/sample_data/Val/msk/5619.png
#   inflating: /content/sample_data/Val/msk/562.png
#   inflating: /content/sample_data/Val/msk/5620.png
#   inflating: /content/sample_data/Val/msk/5621.png
#   inflating: /content/sample_data/Val/msk/5622.png
#   inflating: /content/sample_data/Val/msk/5623.png
#   inflating: /content/sample_data/Val/msk/5624.png
#   inflating: /content/sample_data/Val/msk/5625.png
#   inflating: /content/sample_data/Val/msk/5626.png
#   inflating: /content/sample_data/Val/msk/5627.png
#   inflating: /content/sample_data/Val/msk/5628.png
#   inflating: /content/sample_data/Val/msk/5629.png
#   inflating: /content/sample_data/Val/msk/563.png
#   inflating: /content/sample_data/Val/msk/5630.png
#   inflating: /content/sample_data/Val/msk/5631.png
#   inflating: /content/sample_data/Val/msk/5632.png
#   inflating: /content/sample_data/Val/msk/5633.png
#   inflating: /content/sample_data/Val/msk/5634.png
#   inflating: /content/sample_data/Val/msk/5635.png
#   inflating: /content/sample_data/Val/msk/5636.png
#   inflating: /content/sample_data/Val/msk/5637.png
#   inflating: /content/sample_data/Val/msk/5638.png
#   inflating: /content/sample_data/Val/msk/5639.png
#   inflating: /content/sample_data/Val/msk/564.png
#   inflating: /content/sample_data/Val/msk/5640.png
#   inflating: /content/sample_data/Val/msk/5641.png
#   inflating: /content/sample_data/Val/msk/5642.png
#   inflating: /content/sample_data/Val/msk/5643.png
#   inflating: /content/sample_data/Val/msk/5644.png
#   inflating: /content/sample_data/Val/msk/5645.png
#   inflating: /content/sample_data/Val/msk/5646.png
#   inflating: /content/sample_data/Val/msk/5647.png
#   inflating: /content/sample_data/Val/msk/5648.png
#   inflating: /content/sample_data/Val/msk/5649.png
#   inflating: /content/sample_data/Val/msk/5650.png
#   inflating: /content/sample_data/Val/msk/5651.png
#   inflating: /content/sample_data/Val/msk/5652.png
#   inflating: /content/sample_data/Val/msk/5653.png
#   inflating: /content/sample_data/Val/msk/5654.png
#   inflating: /content/sample_data/Val/msk/5655.png
#   inflating: /content/sample_data/Val/msk/5656.png
#   inflating: /content/sample_data/Val/msk/5657.png
#   inflating: /content/sample_data/Val/msk/5658.png
#   inflating: /content/sample_data/Val/msk/5659.png
#   inflating: /content/sample_data/Val/msk/5660.png
#   inflating: /content/sample_data/Val/msk/5661.png
#   inflating: /content/sample_data/Val/msk/5662.png
#   inflating: /content/sample_data/Val/msk/5663.png
#   inflating: /content/sample_data/Val/msk/5664.png
#   inflating: /content/sample_data/Val/msk/5665.png
#   inflating: /content/sample_data/Val/msk/5666.png
#   inflating: /content/sample_data/Val/msk/5667.png
#   inflating: /content/sample_data/Val/msk/5668.png
#   inflating: /content/sample_data/Val/msk/5669.png
#   inflating: /content/sample_data/Val/msk/5670.png
#   inflating: /content/sample_data/Val/msk/5671.png
#   inflating: /content/sample_data/Val/msk/5672.png
#   inflating: /content/sample_data/Val/msk/5673.png
#   inflating: /content/sample_data/Val/msk/5674.png
#   inflating: /content/sample_data/Val/msk/5675.png
#   inflating: /content/sample_data/Val/msk/5676.png
#   inflating: /content/sample_data/Val/msk/5677.png
#   inflating: /content/sample_data/Val/msk/5678.png
#   inflating: /content/sample_data/Val/msk/5679.png
#   inflating: /content/sample_data/Val/msk/5680.png
#   inflating: /content/sample_data/Val/msk/5681.png
#   inflating: /content/sample_data/Val/msk/5682.png
#   inflating: /content/sample_data/Val/msk/5683.png
#   inflating: /content/sample_data/Val/msk/5684.png
#   inflating: /content/sample_data/Val/msk/5685.png
#   inflating: /content/sample_data/Val/msk/5686.png
#   inflating: /content/sample_data/Val/msk/5687.png
#   inflating: /content/sample_data/Val/msk/5688.png
#   inflating: /content/sample_data/Val/msk/5689.png
#   inflating: /content/sample_data/Val/msk/5690.png
#   inflating: /content/sample_data/Val/msk/5691.png
#   inflating: /content/sample_data/Val/msk/5697.png
#   inflating: /content/sample_data/Val/msk/5698.png
#   inflating: /content/sample_data/Val/msk/5699.png
#   inflating: /content/sample_data/Val/msk/57.png
#   inflating: /content/sample_data/Val/msk/570.png
#   inflating: /content/sample_data/Val/msk/5700.png
#   inflating: /content/sample_data/Val/msk/5701.png
#   inflating: /content/sample_data/Val/msk/5702.png
#   inflating: /content/sample_data/Val/msk/5703.png
#   inflating: /content/sample_data/Val/msk/5704.png
#   inflating: /content/sample_data/Val/msk/5705.png
#   inflating: /content/sample_data/Val/msk/5706.png
#   inflating: /content/sample_data/Val/msk/5707.png
#   inflating: /content/sample_data/Val/msk/5708.png
#   inflating: /content/sample_data/Val/msk/5709.png
#   inflating: /content/sample_data/Val/msk/5715.png
#   inflating: /content/sample_data/Val/msk/5716.png
#   inflating: /content/sample_data/Val/msk/5717.png
#   inflating: /content/sample_data/Val/msk/5718.png
#   inflating: /content/sample_data/Val/msk/5719.png
#   inflating: /content/sample_data/Val/msk/5720.png
#   inflating: /content/sample_data/Val/msk/5721.png
#   inflating: /content/sample_data/Val/msk/5727.png
#   inflating: /content/sample_data/Val/msk/5733.png
#   inflating: /content/sample_data/Val/msk/5734.png
#   inflating: /content/sample_data/Val/msk/5735.png
#   inflating: /content/sample_data/Val/msk/5736.png
#   inflating: /content/sample_data/Val/msk/5737.png
#   inflating: /content/sample_data/Val/msk/5738.png
#   inflating: /content/sample_data/Val/msk/5739.png
#   inflating: /content/sample_data/Val/msk/5740.png
#   inflating: /content/sample_data/Val/msk/5741.png
#   inflating: /content/sample_data/Val/msk/5742.png
#   inflating: /content/sample_data/Val/msk/5743.png
#   inflating: /content/sample_data/Val/msk/5744.png
#   inflating: /content/sample_data/Val/msk/5745.png
#   inflating: /content/sample_data/Val/msk/5746.png
#   inflating: /content/sample_data/Val/msk/5747.png
#   inflating: /content/sample_data/Val/msk/5748.png
#   inflating: /content/sample_data/Val/msk/5749.png
#   inflating: /content/sample_data/Val/msk/5750.png
#   inflating: /content/sample_data/Val/msk/5751.png
#   inflating: /content/sample_data/Val/msk/5752.png
#   inflating: /content/sample_data/Val/msk/5753.png
#   inflating: /content/sample_data/Val/msk/5754.png
#   inflating: /content/sample_data/Val/msk/5755.png
#   inflating: /content/sample_data/Val/msk/5756.png
#   inflating: /content/sample_data/Val/msk/5757.png
#   inflating: /content/sample_data/Val/msk/5758.png
#   inflating: /content/sample_data/Val/msk/5759.png
#   inflating: /content/sample_data/Val/msk/576.png
#   inflating: /content/sample_data/Val/msk/5760.png
#   inflating: /content/sample_data/Val/msk/5761.png
#   inflating: /content/sample_data/Val/msk/5762.png
#   inflating: /content/sample_data/Val/msk/5763.png
#   inflating: /content/sample_data/Val/msk/5764.png
#   inflating: /content/sample_data/Val/msk/5765.png
#   inflating: /content/sample_data/Val/msk/5766.png
#   inflating: /content/sample_data/Val/msk/5767.png
#   inflating: /content/sample_data/Val/msk/5768.png
#   inflating: /content/sample_data/Val/msk/5769.png
#   inflating: /content/sample_data/Val/msk/5775.png
#   inflating: /content/sample_data/Val/msk/5781.png
#   inflating: /content/sample_data/Val/msk/5782.png
#   inflating: /content/sample_data/Val/msk/5783.png
#   inflating: /content/sample_data/Val/msk/5784.png
#   inflating: /content/sample_data/Val/msk/5785.png
#   inflating: /content/sample_data/Val/msk/5786.png
#   inflating: /content/sample_data/Val/msk/5787.png
#   inflating: /content/sample_data/Val/msk/5788.png
#   inflating: /content/sample_data/Val/msk/5789.png
#   inflating: /content/sample_data/Val/msk/5790.png
#   inflating: /content/sample_data/Val/msk/5791.png
#   inflating: /content/sample_data/Val/msk/5792.png
#   inflating: /content/sample_data/Val/msk/5793.png
#   inflating: /content/sample_data/Val/msk/5794.png
#   inflating: /content/sample_data/Val/msk/5795.png
#   inflating: /content/sample_data/Val/msk/5796.png
#   inflating: /content/sample_data/Val/msk/5797.png
#   inflating: /content/sample_data/Val/msk/5798.png
#   inflating: /content/sample_data/Val/msk/5799.png
#   inflating: /content/sample_data/Val/msk/58.png
#   inflating: /content/sample_data/Val/msk/5800.png
#   inflating: /content/sample_data/Val/msk/5801.png
#   inflating: /content/sample_data/Val/msk/5802.png
#   inflating: /content/sample_data/Val/msk/5803.png
#   inflating: /content/sample_data/Val/msk/5804.png
#   inflating: /content/sample_data/Val/msk/5805.png
#   inflating: /content/sample_data/Val/msk/5806.png
#   inflating: /content/sample_data/Val/msk/5807.png
#   inflating: /content/sample_data/Val/msk/5808.png
#   inflating: /content/sample_data/Val/msk/5809.png
#   inflating: /content/sample_data/Val/msk/5810.png
#   inflating: /content/sample_data/Val/msk/5811.png
#   inflating: /content/sample_data/Val/msk/5812.png
#   inflating: /content/sample_data/Val/msk/5813.png
#   inflating: /content/sample_data/Val/msk/5814.png
#   inflating: /content/sample_data/Val/msk/5815.png
#   inflating: /content/sample_data/Val/msk/5816.png
#   inflating: /content/sample_data/Val/msk/5817.png
#   inflating: /content/sample_data/Val/msk/5818.png
#   inflating: /content/sample_data/Val/msk/5819.png
#   inflating: /content/sample_data/Val/msk/582.png
#   inflating: /content/sample_data/Val/msk/5820.png
#   inflating: /content/sample_data/Val/msk/5821.png
#   inflating: /content/sample_data/Val/msk/5822.png
#   inflating: /content/sample_data/Val/msk/5823.png
#   inflating: /content/sample_data/Val/msk/5824.png
#   inflating: /content/sample_data/Val/msk/5825.png
#   inflating: /content/sample_data/Val/msk/5826.png
#   inflating: /content/sample_data/Val/msk/5827.png
#   inflating: /content/sample_data/Val/msk/5828.png
#   inflating: /content/sample_data/Val/msk/5829.png
#   inflating: /content/sample_data/Val/msk/5830.png
#   inflating: /content/sample_data/Val/msk/5831.png
#   inflating: /content/sample_data/Val/msk/5832.png
#   inflating: /content/sample_data/Val/msk/5833.png
#   inflating: /content/sample_data/Val/msk/5834.png
#   inflating: /content/sample_data/Val/msk/5835.png
#   inflating: /content/sample_data/Val/msk/5836.png
#   inflating: /content/sample_data/Val/msk/5837.png
#   inflating: /content/sample_data/Val/msk/5838.png
#   inflating: /content/sample_data/Val/msk/5839.png
#   inflating: /content/sample_data/Val/msk/5840.png
#   inflating: /content/sample_data/Val/msk/5841.png
#   inflating: /content/sample_data/Val/msk/5842.png
#   inflating: /content/sample_data/Val/msk/5843.png
#   inflating: /content/sample_data/Val/msk/5844.png
#   inflating: /content/sample_data/Val/msk/5845.png
#   inflating: /content/sample_data/Val/msk/5846.png
#   inflating: /content/sample_data/Val/msk/5847.png
#   inflating: /content/sample_data/Val/msk/5853.png
#   inflating: /content/sample_data/Val/msk/5854.png
#   inflating: /content/sample_data/Val/msk/5855.png
#   inflating: /content/sample_data/Val/msk/5856.png
#   inflating: /content/sample_data/Val/msk/5857.png
#   inflating: /content/sample_data/Val/msk/5858.png
#   inflating: /content/sample_data/Val/msk/5859.png
#   inflating: /content/sample_data/Val/msk/5860.png
#   inflating: /content/sample_data/Val/msk/5861.png
#   inflating: /content/sample_data/Val/msk/5862.png
#   inflating: /content/sample_data/Val/msk/5863.png
#   inflating: /content/sample_data/Val/msk/5864.png
#   inflating: /content/sample_data/Val/msk/5865.png
#   inflating: /content/sample_data/Val/msk/5866.png
#   inflating: /content/sample_data/Val/msk/5867.png
#   inflating: /content/sample_data/Val/msk/5868.png
#   inflating: /content/sample_data/Val/msk/5869.png
#   inflating: /content/sample_data/Val/msk/5870.png
#   inflating: /content/sample_data/Val/msk/5871.png
#   inflating: /content/sample_data/Val/msk/5872.png
#   inflating: /content/sample_data/Val/msk/5873.png
#   inflating: /content/sample_data/Val/msk/5874.png
#   inflating: /content/sample_data/Val/msk/5875.png
#   inflating: /content/sample_data/Val/msk/5876.png
#   inflating: /content/sample_data/Val/msk/5877.png
#   inflating: /content/sample_data/Val/msk/5878.png
#   inflating: /content/sample_data/Val/msk/5879.png
#   inflating: /content/sample_data/Val/msk/588.png
#   inflating: /content/sample_data/Val/msk/5880.png
#   inflating: /content/sample_data/Val/msk/5881.png
# ...
#   inflating: /content/sample_data/Val/msk/9678.png
#   inflating: /content/sample_data/Val/msk/9679.png
#   inflating: /content/sample_data/Val/msk/968.png
#   inflating: /content/sample_data/Val/msk/9680.png
#   inflating: /content/sample_data/Val/msk/9681.png
#   inflating: /content/sample_data/Val/msk/9682.png
#   inflating: /content/sample_data/Val/msk/9683.png
#   inflating: /content/sample_data/Val/msk/9684.png
#   inflating: /content/sample_data/Val/msk/9685.png
#   inflating: /content/sample_data/Val/msk/9686.png
#   inflating: /content/sample_data/Val/msk/9687.png
#   inflating: /content/sample_data/Val/msk/9688.png
#   inflating: /content/sample_data/Val/msk/9689.png
#   inflating: /content/sample_data/Val/msk/969.png
#   inflating: /content/sample_data/Val/msk/9695.png
#   inflating: /content/sample_data/Val/msk/9696.png
#   inflating: /content/sample_data/Val/msk/9697.png
#   inflating: /content/sample_data/Val/msk/9698.png
#   inflating: /content/sample_data/Val/msk/9699.png
#   inflating: /content/sample_data/Val/msk/97.png
#   inflating: /content/sample_data/Val/msk/970.png
#   inflating: /content/sample_data/Val/msk/9700.png
#   inflating: /content/sample_data/Val/msk/9701.png
#   inflating: /content/sample_data/Val/msk/9702.png
#   inflating: /content/sample_data/Val/msk/9703.png
#   inflating: /content/sample_data/Val/msk/9704.png
#   inflating: /content/sample_data/Val/msk/9705.png
#   inflating: /content/sample_data/Val/msk/9706.png
#   inflating: /content/sample_data/Val/msk/9707.png
#   inflating: /content/sample_data/Val/msk/9708.png
#   inflating: /content/sample_data/Val/msk/9709.png
#   inflating: /content/sample_data/Val/msk/971.png
#   inflating: /content/sample_data/Val/msk/9710.png
#   inflating: /content/sample_data/Val/msk/9711.png
#   inflating: /content/sample_data/Val/msk/9712.png
#   inflating: /content/sample_data/Val/msk/9713.png
#   inflating: /content/sample_data/Val/msk/9714.png
#   inflating: /content/sample_data/Val/msk/9715.png
#   inflating: /content/sample_data/Val/msk/9716.png
#   inflating: /content/sample_data/Val/msk/9717.png
#   inflating: /content/sample_data/Val/msk/9718.png
#   inflating: /content/sample_data/Val/msk/9719.png
#   inflating: /content/sample_data/Val/msk/972.png
#   inflating: /content/sample_data/Val/msk/9720.png
#   inflating: /content/sample_data/Val/msk/9721.png
#   inflating: /content/sample_data/Val/msk/9722.png
#   inflating: /content/sample_data/Val/msk/9723.png
#   inflating: /content/sample_data/Val/msk/9724.png
#   inflating: /content/sample_data/Val/msk/9725.png
#   inflating: /content/sample_data/Val/msk/9726.png
#   inflating: /content/sample_data/Val/msk/9727.png
#   inflating: /content/sample_data/Val/msk/9728.png
#   inflating: /content/sample_data/Val/msk/9729.png
#   inflating: /content/sample_data/Val/msk/973.png
#   inflating: /content/sample_data/Val/msk/9730.png
#   inflating: /content/sample_data/Val/msk/9731.png
#   inflating: /content/sample_data/Val/msk/9732.png
#   inflating: /content/sample_data/Val/msk/9733.png
#   inflating: /content/sample_data/Val/msk/9734.png
#   inflating: /content/sample_data/Val/msk/9735.png
#   inflating: /content/sample_data/Val/msk/9736.png
#   inflating: /content/sample_data/Val/msk/9737.png
#   inflating: /content/sample_data/Val/msk/9738.png
#   inflating: /content/sample_data/Val/msk/9739.png
#   inflating: /content/sample_data/Val/msk/974.png
#   inflating: /content/sample_data/Val/msk/9740.png
#   inflating: /content/sample_data/Val/msk/9741.png
#   inflating: /content/sample_data/Val/msk/9742.png
#   inflating: /content/sample_data/Val/msk/9743.png
#   inflating: /content/sample_data/Val/msk/9744.png
#   inflating: /content/sample_data/Val/msk/9745.png
#   inflating: /content/sample_data/Val/msk/9746.png
#   inflating: /content/sample_data/Val/msk/9747.png
#   inflating: /content/sample_data/Val/msk/9748.png
#   inflating: /content/sample_data/Val/msk/9749.png
#   inflating: /content/sample_data/Val/msk/975.png
#   inflating: /content/sample_data/Val/msk/9750.png
#   inflating: /content/sample_data/Val/msk/9751.png
#   inflating: /content/sample_data/Val/msk/9752.png
#   inflating: /content/sample_data/Val/msk/9753.png
#   inflating: /content/sample_data/Val/msk/9754.png
#   inflating: /content/sample_data/Val/msk/9755.png
#   inflating: /content/sample_data/Val/msk/9756.png
#   inflating: /content/sample_data/Val/msk/9757.png
#   inflating: /content/sample_data/Val/msk/9758.png
#   inflating: /content/sample_data/Val/msk/9759.png
#   inflating: /content/sample_data/Val/msk/976.png
#   inflating: /content/sample_data/Val/msk/9760.png
#   inflating: /content/sample_data/Val/msk/9761.png
#   inflating: /content/sample_data/Val/msk/9762.png
#   inflating: /content/sample_data/Val/msk/9763.png
#   inflating: /content/sample_data/Val/msk/9764.png
#   inflating: /content/sample_data/Val/msk/9765.png
#   inflating: /content/sample_data/Val/msk/9766.png
#   inflating: /content/sample_data/Val/msk/9767.png
#   inflating: /content/sample_data/Val/msk/9768.png
#   inflating: /content/sample_data/Val/msk/9769.png
#   inflating: /content/sample_data/Val/msk/977.png
#   inflating: /content/sample_data/Val/msk/9770.png
#   inflating: /content/sample_data/Val/msk/9771.png
#   inflating: /content/sample_data/Val/msk/9772.png
#   inflating: /content/sample_data/Val/msk/9773.png
#   inflating: /content/sample_data/Val/msk/9779.png
#   inflating: /content/sample_data/Val/msk/978.png
#   inflating: /content/sample_data/Val/msk/9785.png
#   inflating: /content/sample_data/Val/msk/979.png
#   inflating: /content/sample_data/Val/msk/9791.png
#   inflating: /content/sample_data/Val/msk/9792.png
#   inflating: /content/sample_data/Val/msk/9793.png
#   inflating: /content/sample_data/Val/msk/9794.png
#   inflating: /content/sample_data/Val/msk/9795.png
#   inflating: /content/sample_data/Val/msk/9796.png
#   inflating: /content/sample_data/Val/msk/9797.png
#   inflating: /content/sample_data/Val/msk/9798.png
#   inflating: /content/sample_data/Val/msk/9799.png
#   inflating: /content/sample_data/Val/msk/98.png
#   inflating: /content/sample_data/Val/msk/980.png
#   inflating: /content/sample_data/Val/msk/9800.png
#   inflating: /content/sample_data/Val/msk/9801.png
#   inflating: /content/sample_data/Val/msk/9802.png
#   inflating: /content/sample_data/Val/msk/9803.png
#   inflating: /content/sample_data/Val/msk/9804.png
#   inflating: /content/sample_data/Val/msk/9805.png
#   inflating: /content/sample_data/Val/msk/9806.png
#   inflating: /content/sample_data/Val/msk/9807.png
#   inflating: /content/sample_data/Val/msk/9808.png
#   inflating: /content/sample_data/Val/msk/9809.png
#   inflating: /content/sample_data/Val/msk/981.png
#   inflating: /content/sample_data/Val/msk/9815.png
#   inflating: /content/sample_data/Val/msk/982.png
#   inflating: /content/sample_data/Val/msk/9821.png
#   inflating: /content/sample_data/Val/msk/9827.png
#   inflating: /content/sample_data/Val/msk/9828.png
#   inflating: /content/sample_data/Val/msk/9829.png
#   inflating: /content/sample_data/Val/msk/983.png
#   inflating: /content/sample_data/Val/msk/9830.png
#   inflating: /content/sample_data/Val/msk/9831.png
#   inflating: /content/sample_data/Val/msk/9832.png
#   inflating: /content/sample_data/Val/msk/9833.png
#   inflating: /content/sample_data/Val/msk/9834.png
#   inflating: /content/sample_data/Val/msk/9835.png
#   inflating: /content/sample_data/Val/msk/9836.png
#   inflating: /content/sample_data/Val/msk/9837.png
#   inflating: /content/sample_data/Val/msk/9838.png
#   inflating: /content/sample_data/Val/msk/9839.png
#   inflating: /content/sample_data/Val/msk/984.png
#   inflating: /content/sample_data/Val/msk/9840.png
#   inflating: /content/sample_data/Val/msk/9841.png
#   inflating: /content/sample_data/Val/msk/9842.png
#   inflating: /content/sample_data/Val/msk/9843.png
#   inflating: /content/sample_data/Val/msk/9844.png
#   inflating: /content/sample_data/Val/msk/9845.png
#   inflating: /content/sample_data/Val/msk/9846.png
#   inflating: /content/sample_data/Val/msk/9847.png
#   inflating: /content/sample_data/Val/msk/9848.png
#   inflating: /content/sample_data/Val/msk/9849.png
#   inflating: /content/sample_data/Val/msk/985.png
#   inflating: /content/sample_data/Val/msk/9850.png
#   inflating: /content/sample_data/Val/msk/9851.png
#   inflating: /content/sample_data/Val/msk/9852.png
#   inflating: /content/sample_data/Val/msk/9853.png
#   inflating: /content/sample_data/Val/msk/9854.png
#   inflating: /content/sample_data/Val/msk/9855.png
#   inflating: /content/sample_data/Val/msk/9856.png
#   inflating: /content/sample_data/Val/msk/9857.png
#   inflating: /content/sample_data/Val/msk/9858.png
#   inflating: /content/sample_data/Val/msk/9859.png
#   inflating: /content/sample_data/Val/msk/986.png
#   inflating: /content/sample_data/Val/msk/9860.png
#   inflating: /content/sample_data/Val/msk/9861.png
#   inflating: /content/sample_data/Val/msk/9862.png
#   inflating: /content/sample_data/Val/msk/9863.png
#   inflating: /content/sample_data/Val/msk/9864.png
#   inflating: /content/sample_data/Val/msk/9865.png
#   inflating: /content/sample_data/Val/msk/9866.png
#   inflating: /content/sample_data/Val/msk/9867.png
#   inflating: /content/sample_data/Val/msk/9868.png
#   inflating: /content/sample_data/Val/msk/9869.png
#   inflating: /content/sample_data/Val/msk/987.png
#   inflating: /content/sample_data/Val/msk/9870.png
#   inflating: /content/sample_data/Val/msk/9871.png
#   inflating: /content/sample_data/Val/msk/9872.png
#   inflating: /content/sample_data/Val/msk/9873.png
#   inflating: /content/sample_data/Val/msk/9874.png
#   inflating: /content/sample_data/Val/msk/9875.png
#   inflating: /content/sample_data/Val/msk/9876.png
#   inflating: /content/sample_data/Val/msk/9877.png
#   inflating: /content/sample_data/Val/msk/9878.png
#   inflating: /content/sample_data/Val/msk/9879.png
#   inflating: /content/sample_data/Val/msk/988.png
#   inflating: /content/sample_data/Val/msk/9880.png
#   inflating: /content/sample_data/Val/msk/9881.png
#   inflating: /content/sample_data/Val/msk/9882.png
#   inflating: /content/sample_data/Val/msk/9883.png
#   inflating: /content/sample_data/Val/msk/9884.png
#   inflating: /content/sample_data/Val/msk/9885.png
#   inflating: /content/sample_data/Val/msk/9886.png
#   inflating: /content/sample_data/Val/msk/9887.png
#   inflating: /content/sample_data/Val/msk/9888.png
#   inflating: /content/sample_data/Val/msk/9889.png
#   inflating: /content/sample_data/Val/msk/989.png
#   inflating: /content/sample_data/Val/msk/9890.png
#   inflating: /content/sample_data/Val/msk/9891.png
#   inflating: /content/sample_data/Val/msk/9892.png
#   inflating: /content/sample_data/Val/msk/9893.png
#   inflating: /content/sample_data/Val/msk/9894.png
#   inflating: /content/sample_data/Val/msk/9895.png
#   inflating: /content/sample_data/Val/msk/9896.png
#   inflating: /content/sample_data/Val/msk/9897.png
#   inflating: /content/sample_data/Val/msk/9898.png
#   inflating: /content/sample_data/Val/msk/9899.png
#   inflating: /content/sample_data/Val/msk/99.png
#   inflating: /content/sample_data/Val/msk/990.png
#   inflating: /content/sample_data/Val/msk/9900.png
#   inflating: /content/sample_data/Val/msk/9901.png
#   inflating: /content/sample_data/Val/msk/9902.png
#   inflating: /content/sample_data/Val/msk/9903.png
#   inflating: /content/sample_data/Val/msk/9904.png
#   inflating: /content/sample_data/Val/msk/9905.png
#   inflating: /content/sample_data/Val/msk/9906.png
#   inflating: /content/sample_data/Val/msk/9907.png
#   inflating: /content/sample_data/Val/msk/9908.png
#   inflating: /content/sample_data/Val/msk/9909.png
#   inflating: /content/sample_data/Val/msk/991.png
#   inflating: /content/sample_data/Val/msk/9910.png
#   inflating: /content/sample_data/Val/msk/9911.png
#   inflating: /content/sample_data/Val/msk/9912.png
#   inflating: /content/sample_data/Val/msk/9913.png
#   inflating: /content/sample_data/Val/msk/9914.png
#   inflating: /content/sample_data/Val/msk/9915.png
#   inflating: /content/sample_data/Val/msk/9916.png
#   inflating: /content/sample_data/Val/msk/9917.png
#   inflating: /content/sample_data/Val/msk/9918.png
#   inflating: /content/sample_data/Val/msk/9919.png
#   inflating: /content/sample_data/Val/msk/992.png
#   inflating: /content/sample_data/Val/msk/9920.png
#   inflating: /content/sample_data/Val/msk/9921.png
#   inflating: /content/sample_data/Val/msk/9922.png
#   inflating: /content/sample_data/Val/msk/9923.png
#   inflating: /content/sample_data/Val/msk/9924.png
#   inflating: /content/sample_data/Val/msk/9925.png
#   inflating: /content/sample_data/Val/msk/9926.png
#   inflating: /content/sample_data/Val/msk/9927.png
#   inflating: /content/sample_data/Val/msk/9928.png
#   inflating: /content/sample_data/Val/msk/9929.png
#   inflating: /content/sample_data/Val/msk/993.png
#   inflating: /content/sample_data/Val/msk/9930.png
#   inflating: /content/sample_data/Val/msk/9931.png
#   inflating: /content/sample_data/Val/msk/9932.png
#   inflating: /content/sample_data/Val/msk/9933.png
#   inflating: /content/sample_data/Val/msk/9934.png
#   inflating: /content/sample_data/Val/msk/9935.png
#   inflating: /content/sample_data/Val/msk/994.png
#   inflating: /content/sample_data/Val/msk/9941.png
#   inflating: /content/sample_data/Val/msk/9947.png
#   inflating: /content/sample_data/Val/msk/995.png
#   inflating: /content/sample_data/Val/msk/9953.png
#   inflating: /content/sample_data/Val/msk/9959.png
#   inflating: /content/sample_data/Val/msk/996.png
#   inflating: /content/sample_data/Val/msk/9960.png
#   inflating: /content/sample_data/Val/msk/9961.png
#   inflating: /content/sample_data/Val/msk/9962.png
#   inflating: /content/sample_data/Val/msk/9963.png
#   inflating: /content/sample_data/Val/msk/9964.png
#   inflating: /content/sample_data/Val/msk/9965.png
#   inflating: /content/sample_data/Val/msk/9966.png
#   inflating: /content/sample_data/Val/msk/9967.png
#   inflating: /content/sample_data/Val/msk/9968.png
#   inflating: /content/sample_data/Val/msk/9969.png
#   inflating: /content/sample_data/Val/msk/997.png
#   inflating: /content/sample_data/Val/msk/9970.png
#   inflating: /content/sample_data/Val/msk/9971.png
#   inflating: /content/sample_data/Val/msk/9972.png
#   inflating: /content/sample_data/Val/msk/9973.png
#   inflating: /content/sample_data/Val/msk/9974.png
#   inflating: /content/sample_data/Val/msk/9975.png
#   inflating: /content/sample_data/Val/msk/9976.png
#   inflating: /content/sample_data/Val/msk/9977.png
#   inflating: /content/sample_data/Val/msk/9978.png
#   inflating: /content/sample_data/Val/msk/9979.png
#   inflating: /content/sample_data/Val/msk/998.png
#   inflating: /content/sample_data/Val/msk/9980.png
#   inflating: /content/sample_data/Val/msk/9981.png
#   inflating: /content/sample_data/Val/msk/9982.png
#   inflating: /content/sample_data/Val/msk/9983.png
#   inflating: /content/sample_data/Val/msk/9984.png
#   inflating: /content/sample_data/Val/msk/9985.png
#   inflating: /content/sample_data/Val/msk/9986.png
#   inflating: /content/sample_data/Val/msk/9987.png
#   inflating: /content/sample_data/Val/msk/9988.png
#   inflating: /content/sample_data/Val/msk/9989.png
#   inflating: /content/sample_data/Val/msk/999.png
#   inflating: /content/sample_data/Val/msk/9990.png
#   inflating: /content/sample_data/Val/msk/9991.png
#   inflating: /content/sample_data/Val/msk/9992.png
#   inflating: /content/sample_data/Val/msk/9993.png
#   inflating: /content/sample_data/Val/msk/9994.png
#   inflating: /content/sample_data/Val/msk/9995.png
#   inflating: /content/sample_data/Val/msk/9996.png
#   inflating: /content/sample_data/Val/msk/9997.png
#   inflating: /content/sample_data/Val/msk/9998.png
#   inflating: /content/sample_data/Val/msk/9999.png

# %%
ent_input_dir= "/content/sample_data/Ent/img"
ent_target_dir= "/content/sample_data/Ent/msk"

val_input_dir= "/content/sample_data/Val/img"
val_target_dir= "/content/sample_data/Val/msk"

input_img_paths = sorted(
    [
        os.path.join(ent_input_dir, fname)
        for fname in os.listdir(ent_input_dir) 
        if fname.endswith(".png")
    ]
)

target_img_paths = sorted(
    [
        os.path.join(ent_target_dir, fname)
        for fname in os.listdir(ent_target_dir)
        if fname.endswith(".png") and not fname.startswith(".")
    ]
)

val_input_paths = sorted(
    [
        os.path.join(val_input_dir, fname)
        for fname in os.listdir(val_input_dir)
        if fname.endswith(".png") and not fname.startswith(".")
    ]
)

val_target_paths = sorted(
    [
        os.path.join(val_target_dir, fname)
        for fname in os.listdir(val_target_dir)
        if fname.endswith(".png") and not fname.startswith(".")
    ]
)

no_ent= len(input_img_paths)
no_val= len(val_target_paths)
print(no_ent)
print(no_val)
# Out:
# 136832
# 12662

# %%
class MiClasificacion():
    def __init__(self, No_img, cont= 0, batch_size= 32, img_size= (304, 304)):
        self.batch_size= batch_size
        self.img_size= img_size
        self.cont= cont
        self.steps= No_img// self.batch_size
        self.ID_input= np.arange(No_img)

    def dar_datos(self, img_dir, val_dir):
        if self.steps== self.cont or self.cont== 0:
            np.random.shuffle(self.ID_input)
            self.cont= 0
        
        batch_img= []
        batch_tar= []
        i= self.cont* self.batch_size
        self.cont+= 1

        x = np.zeros((self.batch_size,) + self.img_size + (1,), dtype="float32")
        y = np.zeros((self.batch_size,) + self.img_size + (1,), dtype="uint8") 


        for ig in self.ID_input[i : i + self.batch_size]:
            batch_img.append(img_dir[ig])
            batch_tar.append(val_dir[ig])


        for j, path in enumerate(batch_img):
                img = load_img(path, target_size= self.img_size, color_mode= "grayscale")
                #img= cv2.imread(path)
                #img= cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                x[j,:,:,0] = np.array(img)/255.0  

        for j, path in enumerate(batch_tar):
                img = load_img(path,target_size= self.img_size, color_mode="grayscale")
                y[j] = np.expand_dims(img, 2)
                
                for r in range(y.shape[1]):
                    for g in range(y.shape[2]):
                        if y[j, r, g, 0]!= 0:
                            y[j, r, g, 0]= 1
    
        return x, y

# %%
img_size = (160, 160)
num_classes = 2; batch_size_t = 64; batch_size_v = 64

train_gen = MiClasificacion(no_ent, batch_size= batch_size_t, img_size= img_size)
val_gen = MiClasificacion(no_val, batch_size=batch_size_v, img_size= img_size)

# %% [markdown]
# ### Metricas de medición

# %%
optimizer= tf.keras.optimizers.Adam()
loss_fn= tf.keras.losses.SparseCategoricalCrossentropy(from_logits= False)

train_loss= tf.keras.metrics.Mean(name= 'train_loss')
train_accuracy= tf.keras.metrics.SparseCategoricalAccuracy(name= 'train_accuracy')
train_recall= tf.keras.metrics.Recall(name= 'train_recall')
train_precision= tf.keras.metrics.Precision(name= 'train_precision')


test_loss= tf.keras.metrics.Mean(name= 'test_loss')
test_accuracy= tf.keras.metrics.SparseCategoricalAccuracy(name= 'test_accuracy')
test_recall= tf.keras.metrics.Recall(name= 'test_recall')
test_precision= tf.keras.metrics.Precision(name= 'test_precision')


current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
train_log_dir = '/content/drive/MyDrive/Proyectos/Kika/MetricasModelos/Metricas/' + current_time + '/train'
test_log_dir = '/content/drive/MyDrive/Proyectos/Kika/MetricasModelos/Metricas/' + current_time + '/test'

train_summary_writer = tf.summary.create_file_writer(train_log_dir)
test_summary_writer = tf.summary.create_file_writer(test_log_dir)

# %% [markdown]
# ### Entrenamiento

# %%
@tf.function
def train_step(x, y, y_n):
    
    with tf.GradientTape() as tape:
        predict= mi_modelo(x, training= True)
        loss= loss_fn(y, predict)

    grads= tape.gradient(loss, mi_modelo.trainable_variables)
    optimizer.apply_gradients(zip(grads, mi_modelo.trainable_variables))

    train_loss(loss)
    train_accuracy(y, predict)
    train_recall(y_n, predict)
    train_precision(y_n, predict)

@tf.function
def test_step(x, y, y_n):
    
    predictions= mi_modelo(x, training= False)
    loss= loss_fn(y, predictions)

    test_loss(loss)
    test_accuracy(y, predictions)
    test_recall(y_n, predictions)
    test_precision(y_n, predictions)

# %%
def cambio_tam(img, msk):
    gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

    gray = cv.GaussianBlur(gray, (7, 7), 3)
    t, dst = cv.threshold(gray, 0, 255, cv.THRESH_BINARY | cv.THRESH_TRIANGLE)
    contours, _= cv.findContours(dst, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
    img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    a = []

    for c in contours:
        area = cv.contourArea(c)
        a.append(area)
        
    for f in contours:
        area = cv.contourArea(f)
        if area == max(a):
            x, y, w, h = cv.boundingRect(f)
            imgr = img[y:y + h, x:x + w]
            mask = msk[y:y + h, x:x + w]

    return imgr, mask

def equalize_clahe_color(img):
    cla = cv.createCLAHE(clipLimit=1.5)     
    channels = cv.split(img)     
    eq_channels = []
    for ch in channels:         
        eq_channels.append(cla.apply(ch))     
        eq_image = cv.merge(eq_channels)     
    return eq_image

def pre_procesamiento(img):
    return cv.cvtColor(equalize_clahe_color(cv.cvtColor(img, cv.COLOR_BGR2RGB)), cv.COLOR_BGR2RGB)

def prediccion_m(model, img):
  img= (np.array(img).reshape(-1,160,160, 1))/255.0
  val_preds = model(img, training= False)
  mask = np.argmax(val_preds[0], axis=-1)
  mask = np.expand_dims(mask, axis=-1)
  img = PIL.ImageOps.autocontrast(tf.keras.preprocessing.image.array_to_img(mask))
  
  return np.array(img)

# Genera los patches de entrada para el modelo
def generar_patch(img, tam= 320):
    f= []; g= 0; c= 0
    for t in range(int(img.shape[0]/tam)):
        for j in range(int(img.shape[1]/tam)):
            f.append(img[g:g+ tam, c: c+ tam])
            c+= tam
        if img.shape[1]% tam != 0:
            f.append(cv.resize(img[g:g+ tam, c: c+ (img.shape[1]-c)], (tam, tam), interpolation = cv.INTER_AREA))
        g+= tam; c= 0
        
    for t in range(int(img.shape[1]/tam)):
        f.append(cv.resize(img[g:g+ (img.shape[0]- g), c: c+ tam], (tam, tam), interpolation = cv.INTER_AREA))
        c+= tam
    if img.shape[1]% tam != 0:
        f.append(cv.resize(img[g:g+ (img.shape[0]-g), c: c+ (img.shape[1]-c)], (tam,tam), interpolation = cv.INTER_AREA))
    
    return f

def construccion_img(img, model, f, n= 0, c= 0, g= 0, tam= 320):
    img_pred= np.zeros((img.shape[0], img.shape[1]))
    for t in range(int(img.shape[0]/tam)):
        for j in range(int(img.shape[1]/tam)):
            p= prediccion_m(model, f[n])
            img_pred[g: g+ tam, c: c+ tam]= p
            c+= tam; n+= 1
        if img.shape[1]% tam != 0:
            p= cv.resize(prediccion_m(model, f[n]), (img.shape[1]-c, tam), interpolation = cv.INTER_AREA)
            img_pred[g: g+ tam, c:]= p
        g+= tam; c= 0; n+= 1
        
    for t in range(int(img.shape[1]/tam)):
        p= cv.resize(prediccion_m(model, f[n]), (tam, img.shape[0]-g), interpolation = cv.INTER_AREA)
        img_pred[g:, c: c+ tam]= p
        c+= tam; n+= 1
    if img.shape[1]% tam != 0:
        p= cv.resize(prediccion_m(model, f[n]), (img.shape[1]-c, img.shape[0]-g), interpolation = cv.INTER_AREA)
        img_pred[g:, c:]= p
    
    return img_pred

def imagenes_comp(img, mask, s1= None, s2= None, s3= None, mostrar= False, guardar= False):
  img_t= np.zeros((img.shape[0], img.shape[1], 3), dtype= np.float)
  conv= np.zeros((img.shape[0], img.shape[1], 3), dtype= np.float)
  img_t[:, :, 1]= img

  conv[:,:,0]= mask[:,:,0]
  conv[:,:,1]= img

  if mostrar== True:
    #plt.imshow(img_t, cmap= 'gray')
    #plt.show()

    #plt.imshow(mask, cmap= 'gray')
    #plt.show()

    plt.imshow(conv)
    plt.show()
  
  if guardar== True:
    #plt.imsave(s1, img_t/255.0)
    #plt.imsave(s2, mask/255.0)
    plt.imsave(s3, conv/255.0)


def prediccion_final(model, DIR, DIR_M):
  img= cv.imread(DIR)
  mask= tf.keras.preprocessing.image.load_img(DIR_M)
  mask= tf.keras.preprocessing.image.img_to_array(mask)

  img, msk= cambio_tam(img, mask)
  img= equalize_clahe_color(img)
  img= cv.cvtColor(img, cv.COLOR_BGR2GRAY)

  f= generar_patch(img, 160)
  pred= construccion_img(img, model, f, tam= 160)

  return pred, msk

# %%
def mostrar_elementos(DIR, DIR_M, DIR_I, model):
  pred, mask= prediccion_final(model, DIR, DIR_M)
  imagenes_comp(pred, mask, s3= DIR_I, mostrar= True, guardar= True)

# %%
epocas= 50
loss_best= 1500
p_mostrar= int((no_ent//batch_size_t)*.1)

DIR= "/content/drive/MyDrive/Proyectos/Kika/Base de datos/Pruebas/15_dr.JPG"
DIR_M= "/content/drive/MyDrive/Proyectos/Kika/Base de datos/Pruebas/15_dr.tif"
DIR_I= "/content/drive/MyDrive/Proyectos/Kika/MetricasModelos/IMG_E/VGG16/"

for epoca in range(epocas):
  porc=0
  train_loss.reset_states()
  train_accuracy.reset_states()
  train_recall.reset_states()
  train_precision.reset_states()

  test_loss.reset_state()
  test_accuracy.reset_state()
  test_recall.reset_states()
  test_precision.reset_states()

  for t in tqdm(range(int(no_ent/batch_size_t))):
    images, labels= train_gen.dar_datos(input_img_paths, target_img_paths)
    y= tf.keras.utils.to_categorical(labels, num_classes= 2)
    train_step(images, labels, y)

    if t== (p_mostrar* porc):
      mostrar_elementos(DIR, DIR_M, DIR_I+str(porc)+str(epoca)+'.png', mi_modelo)
      print('------------------------------------------')
      porc += 1

  with train_summary_writer.as_default():
    tf.summary.scalar('Loss', train_loss.result(), step=epoca)
    tf.summary.scalar('Accuracy', train_accuracy.result(), step=epoca)
    tf.summary.scalar('Recall', train_recall.result(), step=epoca)
    tf.summary.scalar('Presicion', train_precision.result(), step=epoca)        

  for t in range(int(no_val/batch_size_t)):
    test_im, test_label= val_gen.dar_datos(val_input_paths, val_target_paths)
    y= tf.keras.utils.to_categorical(test_label, num_classes= 2)
    test_step(test_im, test_label, y)
  with test_summary_writer.as_default():
    tf.summary.scalar('Loss_t', test_loss.result(), step=epoca)
    tf.summary.scalar('Accuracy_t', test_accuracy.result(), step=epoca)
    tf.summary.scalar('Recall_t', test_recall.result(), step=epoca)
    tf.summary.scalar('Presicion_t', test_precision.result(), step=epoca) 
  
  if test_loss.result() < loss_best:
    loss_best= test_loss.result()/1
    mi_modelo.save_weights('/content/drive/MyDrive/Proyectos/Kika/MetricasModelos/Modelos/VGG16')
    mi_modelo.save('/content/drive/MyDrive/Proyectos/Kika/MetricasModelos/Modelos/VGG16.h5py')

  print('-------------------------------------------------\n')
  print(
      f'Epoca {epoca+ 1}, '
      f'Loss: {train_loss.result():.3f}, '
      f'Accuracy: {train_accuracy.result()* 100:.3f}, '
      f'Recall: {train_recall.result()* 100:.3f}, '
      f'Precision: {train_precision.result()* 100:.3f} '
      )
      
  print(
      f'Loss_test: {test_loss.result():.3f}, '
      f'Accuracy_test: {test_accuracy.result()* 100:.3f}, '
      f'Recall_test: {test_recall.result()* 100:.3f}, '
      f'Precision_test: {test_precision.result()* 100:.3f} '
  )
  print('\n-------------------------------------------------')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Resultados

# %% [markdown]
# ### Librerias para revisar resultados

# %%
from tensorflow.keras.preprocessing.image import load_img
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from google.colab import drive
from PIL import ImageOps
import tensorflow as tf
import numpy as np
import cv2 as cv
import PIL


drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DIR= '/content/drive/MyDrive/Proyectos/Kika/MetricasModelos/Modelos/VGG16/VGG16.h5py'
model= tf.keras.models.load_model(DIR)
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
def cambio_tam(img, msk):
    gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

    gray = cv.GaussianBlur(gray, (7, 7), 3)
    t, dst = cv.threshold(gray, 0, 255, cv.THRESH_BINARY | cv.THRESH_TRIANGLE)
    contours, _= cv.findContours(dst, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
    img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    a = []

    for c in contours:
        area = cv.contourArea(c)
        a.append(area)
        
    for f in contours:
        area = cv.contourArea(f)
        if area == max(a):
            x, y, w, h = cv.boundingRect(f)
            imgr = img[y:y + h, x:x + w]
            mask = msk[y:y + h, x:x + w]

    return imgr, mask

def equalize_clahe_color(img):
    cla = cv.createCLAHE(clipLimit=1.5)     
    channels = cv.split(img)     
    eq_channels = []
    for ch in channels:         
        eq_channels.append(cla.apply(ch))     
        eq_image = cv.merge(eq_channels)     
    return eq_image

def pre_procesamiento(img):
    return cv.cvtColor(equalize_clahe_color(cv.cvtColor(img, cv.COLOR_BGR2RGB)), cv.COLOR_BGR2RGB)

def prediccion_m(model, img):
  img= (np.array(img).reshape(-1,320,320,3))/255.0
  val_preds = model.predict(img)
  mask = np.argmax(val_preds[0], axis=-1)
  mask = np.expand_dims(mask, axis=-1)
  img = PIL.ImageOps.autocontrast(tf.keras.preprocessing.image.array_to_img(mask))
  
  return np.array(img)

# Genera los patches de entrada para el modelo
def generar_patch(img, tam= 320):
    f= []; g= 0; c= 0
    for t in range(int(img.shape[0]/tam)):
        for j in range(int(img.shape[1]/tam)):
            f.append(img[g:g+ tam, c: c+ tam, :])
            c+= tam
        if img.shape[1]% tam != 0:
            f.append(cv.resize(img[g:g+ tam, c: c+ (img.shape[1]-c), :], (tam, tam), interpolation = cv.INTER_AREA))
        g+= tam; c= 0
        
    for t in range(int(img.shape[1]/tam)):
        f.append(cv.resize(img[g:g+ (img.shape[0]- g), c: c+ tam, :], (tam, tam), interpolation = cv.INTER_AREA))
        c+= tam
    if img.shape[1]% tam != 0:
        f.append(cv.resize(img[g:g+ (img.shape[0]-g), c: c+ (img.shape[1]-c), :], (tam,tam), interpolation = cv.INTER_AREA))
    
    return f

def construccion_img(img, model, f, n= 0, c= 0, g= 0, tam= 320):
    img_pred= np.zeros((img.shape[0], img.shape[1]))
    for t in range(int(img.shape[0]/tam)):
        for j in range(int(img.shape[1]/tam)):
            p= prediccion_m(model, f[n])
            img_pred[g: g+ tam, c: c+ tam]= p
            c+= tam; n+= 1
        if img.shape[1]% tam != 0:
            p= cv.resize(prediccion_m(model, f[n]), (img.shape[1]-c, tam), interpolation = cv.INTER_AREA)
            img_pred[g: g+ tam, c:]= p
        g+= tam; c= 0; n+= 1
        
    for t in range(int(img.shape[1]/tam)):
        p= cv.resize(prediccion_m(model, f[n]), (tam, img.shape[0]-g), interpolation = cv.INTER_AREA)
        img_pred[g:, c: c+ tam]= p
        c+= tam; n+= 1
    if img.shape[1]% tam != 0:
        p= cv.resize(prediccion_m(model, f[n]), (img.shape[1]-c, img.shape[0]-g), interpolation = cv.INTER_AREA)
        img_pred[g:, c:]= p
    
    return img_pred

def imagenes_comp(img, mask, s1= None, s2= None, s3= None, mostrar= False, guardar= False):
  img_t= np.zeros((img.shape[0], img.shape[1], 3), dtype= np.float)
  conv= np.zeros((img.shape[0], img.shape[1], 3), dtype= np.float)
  img_t[:, :, 1]= img

  conv[:,:,0]= mask[:,:,0]
  conv[:,:,1]= img

  if mostrar== True:
    plt.imshow(img_t, cmap= 'gray')
    plt.show()

    plt.imshow(mask, cmap= 'gray')
    plt.show()

    plt.imshow(conv)
    plt.show()
  
  if guardar== True:
    plt.imsave(s1, img_t/255.0)
    plt.imsave(s2, mask/255.0)
    plt.imsave(s3, conv/255.0)


def prediccion_final(model, DIR, DIR_M):
  img= cv.imread(DIR)
  mask= tf.keras.preprocessing.image.load_img(DIR_M)
  mask= tf.keras.preprocessing.image.img_to_array(mask)

  img, msk= cambio_tam(img, mask)
  img= equalize_clahe_color(img)

  f= generar_patch(img)
  pred= construccion_img(img, model, f)

  return pred, msk

# %%
DIR= "/content/drive/MyDrive/Proyectos/Kika/Base de datos/Pruebas/Image_14R.jpg"
DIR_M= "/content/drive/MyDrive/Proyectos/Kika/Base de datos/Pruebas/Image_14R_1stHO.png"

s1= "/content/drive/MyDrive/Proyectos/Sharon/Base de datos/Pruebas/Hemorragias/com/p_vgg.png"
s2= "/content/drive/MyDrive/Proyectos/Sharon/Base de datos/Pruebas/Hemorragias/com/m_vgg.png"
s3= "/content/drive/MyDrive/Proyectos/Sharon/Base de datos/Pruebas/Hemorragias/com/conv_vggm.png"

pred, mask= prediccion_final(model, DIR, DIR_M)

imagenes_comp(pred, mask, s1, s2, s3, True, False)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
DIR= "/content/drive/MyDrive/Proyectos/Kika/Base de datos/Pruebas/40_training.tif"
DIR_M= "/content/drive/MyDrive/Proyectos/Kika/Base de datos/Pruebas/40_manual1.gif"

s1= "/content/drive/MyDrive/Proyectos/Sharon/Base de datos/Pruebas/Hemorragias/com/p_vgg.png"
s2= "/content/drive/MyDrive/Proyectos/Sharon/Base de datos/Pruebas/Hemorragias/com/m_vgg.png"
s3= "/content/drive/MyDrive/Proyectos/Sharon/Base de datos/Pruebas/Hemorragias/com/conv_vggm.png"

pred, mask= prediccion_final(model, DIR, DIR_M)

imagenes_comp(pred, mask, s1, s2, s3, True, False)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
DIR= "/content/drive/MyDrive/Proyectos/Kika/Base de datos/Pruebas/15_h.jpg"
DIR_M= "/content/drive/MyDrive/Proyectos/Kika/Base de datos/Pruebas/15_h.tif"

s1= "/content/drive/MyDrive/Proyectos/Sharon/Base de datos/Pruebas/Hemorragias/com/p_vgg.png"
s2= "/content/drive/MyDrive/Proyectos/Sharon/Base de datos/Pruebas/Hemorragias/com/m_vgg.png"
s3= "/content/drive/MyDrive/Proyectos/Sharon/Base de datos/Pruebas/Hemorragias/com/conv_vggm.png"

pred, mask= prediccion_final(model, DIR, DIR_M)

imagenes_comp(pred, mask, s1, s2, s3, True, False)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
10%25
# Out:
# 10
